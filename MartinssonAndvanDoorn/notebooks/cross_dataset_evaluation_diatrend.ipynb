# %%
# ../artifacts/martinsson_ohio_experiment_6sh/ 
# This is the model saved path with 6 as sampling horizon trained by OhioT1DM dataset

# We need to create another folder with all evaluation yaml file from diatrend dataset but with artifact path as above

# %%
import logging
import sys
import os
import yaml
import pprint
import importlib.util
import tensorflow as tf
import itertools
import copy
import datetime
logging.basicConfig(format='%(asctime)s %(levelname)s %(message)s',
                    level=logging.DEBUG,
                    stream=sys.stdout)

import numpy as np
import metrics
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
# Look at the output of ohio data loader
import xml.etree.ElementTree as ET
import pandas as pd
import numpy as np
import utils
import os
import glob
# Out:
# 2025-02-04 20:40:46,519 DEBUG matplotlib data path: c:\Users\baiyi\.pyenv\pyenv-win\versions\3.10.5\lib\site-packages\matplotlib\mpl-data
# 2025-02-04 20:40:46,526 DEBUG CONFIGDIR=C:\Users\baiyi\.matplotlib
# 2025-02-04 20:40:46,526 DEBUG interactive is False
# 2025-02-04 20:40:46,526 DEBUG platform is win32
# 2025-02-04 20:40:46,550 DEBUG CACHEDIR=C:\Users\baiyi\.matplotlib
# 2025-02-04 20:40:46,550 DEBUG Using fontManager instance from C:\Users\baiyi\.matplotlib\fontlist-v330.json

# %%
def load_module(script_path):
    spec = importlib.util.spec_from_file_location("module.name", script_path)
    module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(module)
    return module

def load_cfg(yaml_filepath):
    """
    Load a YAML configuration file.

    Parameters
    ----------
    yaml_filepath : str

    Returns
    -------
    cfg : dict
    """
    # Read YAML experiment definition file
    with open(yaml_filepath, 'r') as stream:
        cfg = yaml.load(stream)
    cfg = make_paths_absolute(os.path.dirname(yaml_filepath), cfg)
    return cfg

def load_cfgs(yaml_filepath):
    """
    Load YAML configuration files.

    Parameters
    ----------
    yaml_filepath : str

    Returns
    -------
    cfgs : [dict]
    """
    # Read YAML experiment definition file
    with open(yaml_filepath, 'r') as stream:
        cfg = yaml.load(stream, Loader=yaml.SafeLoader)

    cfg = make_paths_absolute(os.path.dirname(yaml_filepath), cfg)

    hyperparameters = []
    hyperparameter_names = []
    hyperparameter_values = []
    # TODO: ugly, should handle arbitrary depth
    for k1 in cfg.keys():
        for k2 in cfg[k1].keys():
            if k2.startswith("param_"):
                hyperparameters.append((k1, k2))
                hyperparameter_names.append((k1, k2[6:]))
                hyperparameter_values.append(cfg[k1][k2])

    hyperparameter_valuess = itertools.product(*hyperparameter_values)


    artifacts_path = cfg['train']['artifacts_path']

    cfgs = []
    for hyperparameter_values in hyperparameter_valuess:
        configuration_name = ""
        for ((k1, k2), value) in zip(hyperparameter_names, hyperparameter_values):
            #print(k1, k2, value)
            cfg[k1][k2] = value
            configuration_name += "{}_{}_".format(k2, str(value))

        cfg['train']['artifacts_path'] = os.path.join(artifacts_path, configuration_name)

        cfgs.append(copy.deepcopy(cfg))

    return cfgs



def make_paths_absolute(dir_, cfg):
    """
    Make all values for keys ending with `_path` absolute to dir_.

    Parameters
    ----------
    dir_ : str
    cfg : dict

    Returns
    -------
    cfg : dict
    """
    for key in cfg.keys():
        if key.endswith("_path"):
            cfg[key] = os.path.join(dir_, cfg[key])
            cfg[key] = os.path.abspath(cfg[key])
            if not os.path.exists(cfg[key]):
                logging.error("%s does not exist.", cfg[key])
        if type(cfg[key]) is dict:
            cfg[key] = make_paths_absolute(dir_, cfg[key])
    return cfg

# %%
def evaluate(model, x_test, y_test, cfg):
    if 'csv_path' in cfg['dataset']:
        basename = os.path.basename(cfg['dataset']['csv_path'])
        patient_id = basename.split('_')[-1].split('.')[0]
    else:
        patient_id = ""
    if 'scale' in cfg['dataset']:
        scale = float(cfg['dataset']['scale'])
    else:
        scale = 1.0
    print(f"Evaluating for patient_id: {patient_id}")
    # load the trained weights
    weights_path = os.path.join(cfg['train']['artifacts_path'], "model.hdf5")
    print("loading weights: {}".format(weights_path))
    model.load_weights(weights_path)

    y_pred = model.predict(x_test)[:,1].flatten()/scale
    y_std  = model.predict(x_test)[:,0].flatten()/scale
    y_test = y_test.flatten()/scale
    t0 = x_test[:,-1,0]/scale

    rmse = metrics.root_mean_squared_error(y_test, y_pred)
    print("patient id: ", patient_id)
    with open(os.path.join(cfg['train']['artifacts_path'], "{}_rmse.txt".format(patient_id)), "w") as outfile:
        outfile.write("{}\n".format(rmse))
    
    # Calculate MAE
    mae = np.mean(np.abs(y_test - y_pred))
    with open(os.path.join(cfg['train']['artifacts_path'], "{}_mae.txt".format(patient_id)), "w") as outfile:
        outfile.write("{}\n".format(mae))

    # Calculate MSE
    # mse = np.mean((y_test - y_pred) ** 2)
    # with open(os.path.join(cfg['train']['artifacts_path'], "{}_mse.txt".format(patient_id)), "w") as outfile:
    #     outfile.write("{}\n".format(mse))

    # Calculate MAPE
    mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100  # Multiply by 100 for percentage
    with open(os.path.join(cfg['train']['artifacts_path'], "{}_mape.txt".format(patient_id)), "w") as outfile:
        outfile.write("{}\n".format(mape))

    # seg = metrics.surveillance_error(y_test, y_pred)
    # with open(os.path.join(cfg['train']['artifacts_path'], "{}_seg.txt".format(patient_id)), "w") as outfile:
    #     outfile.write("{}\n".format(seg))

    # t0_rmse = metrics.root_mean_squared_error(y_test, t0)
    # with open(os.path.join(cfg['train']['artifacts_path'], "{}_t0_rmse.txt".format(patient_id)), "w") as outfile:
    #     outfile.write("{}\n".format(t0_rmse))

    # t0_seg = metrics.surveillance_error(y_test, t0)
    # with open(os.path.join(cfg['train']['artifacts_path'], "{}_t0_seg.txt".format(patient_id)), "w") as outfile:
    #     outfile.write("{}\n".format(t0_seg))

    # with open(os.path.join(cfg['train']['artifacts_path'], "{}_mean_std.txt".format(patient_id)), "w") as outfile:
    #     outfile.write("{}\n".format(np.mean(y_std)))

    # print("RMSE: ", rmse)
    # print("t0 RMSE: ", t0_rmse)
    # print("SEG: ", seg)
    # print("t0 SEG: ", t0_seg)

def train(model, module_train, x_train, y_train, x_valid, y_valid, cfg):
    model = module_train.train(
        model          = model,
        x_train        = x_train,
        y_train        = y_train,
        x_valid        = x_valid,
        y_valid        = y_valid,
        batch_size     = int(cfg['train']['batch_size']),
        epochs         = int(cfg['train']['epochs']),
        patience       = int(cfg['train']['patience']),
        shuffle        = cfg['train']['shuffle'],
        artifacts_path = cfg['train']['artifacts_path']
    )

    return model

def plot_target_distribution(y_test, cfg):
    if 'csv_path' in cfg['dataset']:
        basename = os.path.basename(cfg['dataset']['csv_path'])
        patient_id = basename.split('-')[0]
    else:
        patient_id = ""
    if 'scale' in cfg['dataset']:
        scale = float(cfg['dataset']['scale'])
    else:
        scale = 1.0

    plt.figure()
    sns.distplot(y_test.flatten()/scale, kde=False, norm_hist=True)
    save_path = os.path.join(cfg['train']['artifacts_path'], "{}_dist_plot.pdf".format(patient_id))
    print("saving plot to: ", save_path)
    plt.savefig(save_path, dpi=300)

def plot_nll(model, x_test, y_test, cfg):
    if 'csv_path' in cfg['dataset']:
        basename = os.path.basename(cfg['dataset']['csv_path'])
        patient_id = basename.split('-')[0]
    else:
        patient_id = ""
    if 'scale' in cfg['dataset']:
        scale = float(cfg['dataset']['scale'])
    else:
        scale = 1.0

    # load the trained weights
    model.load_weights(os.path.join(cfg['train']['artifacts_path'], "model.hdf5"))

    #day = (24*60//5)
    start_index = 0
    hours = 8
    to_plot=hours*12
    ticks_per_hour = 12
    ticks = [i*ticks_per_hour for i in range(hours+1)]
    ticks_labels = [str(i) for i in range(hours+1)]

    y_pred      = model.predict(x_test)

    for i in range(5):
        start_index = i*to_plot
        y_pred_std  = y_pred[:,0][start_index:start_index+to_plot]/scale
        y_pred_mean = y_pred[:,1][start_index:start_index+to_plot]/scale
        y_true      = y_test[:,0][start_index:start_index+to_plot]/scale

        xs = np.arange(len(y_true))
        plt.clf()
        plt.ylim([0, 400])
        #plt.ylim([-2, 2])
        plt.plot(xs, y_true, label='ground truth', linestyle='--')
        plt.plot(xs, y_pred_mean, label='prediction')
        plt.fill_between(xs, y_pred_mean-y_pred_std, y_pred_mean+y_pred_std,
                alpha=0.5, edgecolor='#CC4F1B', facecolor='#FF9848')
        plt.xlabel("Time [h]")
        plt.ylabel("Glucose Concentration [mg/dl]")
        plt.legend(loc='upper right')
        #plt.xlabel("y")
        #plt.ylabel("x")
        plt.xticks(ticks, ticks_labels)
        save_path = os.path.join(cfg['train']['artifacts_path'], "{}_nll_plot_{}.pdf".format(patient_id, i))
        print("saving plot to: ", save_path)
        plt.savefig(save_path, dpi=300)

def plot_noise_experiment(model, x_test, y_test, cfg):
    # load the trained weights
    model.load_weights(os.path.join(cfg['train']['artifacts_path'], "model.hdf5"))

    #day = (24*60//5)
    start_index = 0
    hours = 8
    to_plot=hours*12
    ticks_per_hour = 12
    ticks = [i*ticks_per_hour for i in range(hours+1)]
    ticks_labels = [str(i) for i in range(hours+1)]

    y_pred      = model.predict(x_test)

    start_index = 0
    y_pred_std  = y_pred[:,0][start_index:start_index+to_plot]
    y_pred_mean = y_pred[:,1][start_index:start_index+to_plot]
    y_true      = y_test[:,0][start_index:start_index+to_plot]

    xs = np.arange(len(y_true))
    plt.clf()
    #plt.ylim([0, 400])
    plt.ylim([-3, 3])
    plt.plot(xs, y_true, label='ground truth', linestyle='--')
    plt.plot(xs, y_pred_mean, label='prediction')
    plt.fill_between(xs, y_pred_mean-y_pred_std, y_pred_mean+y_pred_std,
            alpha=0.5, edgecolor='#CC4F1B', facecolor='#FF9848')
    #plt.xlabel("Time [h]")
    #plt.ylabel("Glucose Concentration [mg/dl]")
    plt.legend(loc='upper right')
    plt.xlabel("x")
    plt.ylabel("y")
    plt.xticks(ticks, ticks_labels)
    save_path = os.path.join(cfg['train']['artifacts_path'], "noise_experiment_plot.pdf")
    print("saving plot to: ", save_path)
    plt.savefig(save_path, dpi=300)



def plot_seg(model, x_test, y_test, cfg):
    if 'csv_path' in cfg['dataset']:
        basename = os.path.basename(cfg['dataset']['csv_path'])
        patient_id = basename.split('-')[0]
    else:
        patient_id = ""
    if 'scale' in cfg['dataset']:
        scale = float(cfg['dataset']['scale'])
    else:
        scale = 1.0

    # load the trained weights
    model.load_weights(os.path.join(cfg['train']['artifacts_path'], "model.hdf5"))

    y_pred      = model.predict(x_test)
    y_pred_std  = y_pred[:,0][:]/scale
    y_pred_mean = y_pred[:,1][:]/scale
    y_true      = y_test[:,0][:]/scale

    data = np.loadtxt('seg.csv')

    fig, ax = plt.subplots()
    ax.set_title('Patient {} SEG'.format(patient_id))
    ax.set_xlabel('Reference Concentration [mg/dl]')
    ax.set_ylabel('Predicted Concentration [mg/dl]')
    cax = ax.imshow(np.transpose(data), origin='lower', interpolation='nearest')
    cbar = fig.colorbar(cax, ticks=[0.25, 1.0, 2.0, 3.0, 3.75], orientation='vertical')
    cbar.ax.set_yticklabels(['None', 'Mild', 'Moderate', 'High', 'Extreme'],
            rotation=90, va='center')

    plt.scatter(y_true, y_pred_mean, s=25, facecolors='white', edgecolors='black')

    save_path = os.path.join(cfg['train']['artifacts_path'], "{}_seg_plot.pdf".format(patient_id))
    print("saving plot to: ", save_path)
    plt.savefig(save_path, dpi=300)

# %%
yaml_files = glob.glob("./cross_check_vandoorn_diatrend_30min/*.yaml")

yaml_files
# Out:
# ['./cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject10_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject11_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject12_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject13_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject14_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject15_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject16_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject17_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject18_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject19_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject1_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject20_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject21_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject22_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject23_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject24_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject25_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject26_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject27_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject28_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject29_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject2_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject30_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject31_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject32_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject33_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject34_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject35_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject36_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject37_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject38_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject39_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject3_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject40_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject41_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject42_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject43_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject44_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject45_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject46_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject47_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject48_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject49_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject4_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject50_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject51_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject53_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject54_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject5_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject6_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject7_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject8_evaluation.yaml',
#  './cross_check_vandoorn_diatrend_30min\\processed_cgm_data_Subject9_evaluation.yaml']

# %%
mode = "evaluate"
for yaml_filepath in yaml_files:
    cfgs = load_cfgs(yaml_filepath)
    print("Running {} experiments.".format(len(cfgs)))
    for cfg in cfgs:
        seed = int(cfg['train']['seed'])
        np.random.seed(seed)

        # Print the configuration - just to make sure that you loaded what you
        # wanted to load

        module_dataset       = load_module(cfg['dataset']['script_path'])
        module_model         = load_module(cfg['model']['script_path'])
        module_optimizer     = load_module(cfg['optimizer']['script_path'])
        module_loss_function = load_module(cfg['loss_function']['script_path'])
        module_train         = load_module(cfg['train']['script_path'])

        pp = pprint.PrettyPrinter(indent=4)
        pp.pprint(cfg)

        #print("loading dataset ...")
        #nb_past_steps = cfg['dataset']['nb_past_steps']
        #nb_past_steps_tmp = 36
        #cfg['dataset']['nb_past_steps'] = nb_past_steps_tmp
        x_train, y_train, x_valid, y_valid, x_test, y_test = module_dataset.load_dataset(cfg['dataset'])
        #x_train = x_train[:,-nb_past_steps:,:]
        #x_valid = x_valid[:,-nb_past_steps:,:]
        #x_test = x_test[:,-nb_past_steps:,:]
        print("x_train.shape: ", x_train.shape)
        print("y_train.shape: ", y_train.shape)
        print("x_valid.shape: ", x_valid.shape)
        print("y_valid.shape: ", y_valid.shape)
        print("x_test.shape: ", x_test.shape)
        print("y_test.shape: ", y_test.shape)
        #print("loading optimizer ...")
        optimizer = module_optimizer.load(cfg['optimizer'])

        #print("loading loss function ...")
        loss_function = module_loss_function.load()
        #print("loaded function {} ...".format(loss_function.__name__))

        #print("loading model ...")
        if 'tf_nll' in loss_function.__name__:
            model = module_model.load(
                x_train.shape[1:],
                y_train.shape[1]*2,
                cfg['model']
            )
        else:
            model = module_model.load(
                x_train.shape[1:],
                y_train.shape[1],
                cfg['model']
            )

        if 'initial_weights_path' in cfg['train']:
            #print("Loading initial weights: ", cfg['train']['initial_weights_path'])
            model.load_weights(cfg['train']['initial_weights_path'])

        model.compile(
            optimizer=optimizer,
            loss=loss_function
        )

        #print(model.summary())

        # training mode
        if mode == 'train':
            #print("training model ...")
            train(model, module_train, x_train, y_train, x_valid, y_valid, cfg)
        if mode == 'plot_nll':
            plot_nll(model, x_test, y_test, cfg)
        if mode == 'plot_noise_experiment':
            plot_noise_experiment(model, x_test, y_test, cfg)
        if mode == 'plot_seg':
            plot_seg(model, x_test, y_test, cfg)
        if mode == 'plot_dist':
            plot_target_distribution(y_test, cfg)

        # evaluation mode
        if mode == 'evaluate':
            evaluate(model, x_test, y_test, cfg)
# Out:
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject10.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (11829, 6, 1)
# y_test.shape:  (11829, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject10
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 2025-02-04 20:44:34,407 DEBUG Creating converter from 3 to 5
# 370/370 [==============================] - 9s 3ms/step
# 370/370 [==============================] - 1s 2ms/step
# patient id:  Subject10
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject11.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (11623, 6, 1)
# y_test.shape:  (11623, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject11
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 364/364 [==============================] - 1s 3ms/step
# 364/364 [==============================] - 1s 2ms/step
# patient id:  Subject11
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject12.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (11783, 6, 1)
# y_test.shape:  (11783, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject12
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 369/369 [==============================] - 1s 3ms/step
# 369/369 [==============================] - 1s 2ms/step
# patient id:  Subject12
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject13.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (10688, 6, 1)
# y_test.shape:  (10688, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject13
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 334/334 [==============================] - 1s 2ms/step
# 334/334 [==============================] - 1s 2ms/step
# patient id:  Subject13
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject14.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (11428, 6, 1)
# y_test.shape:  (11428, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject14
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 358/358 [==============================] - 1s 2ms/step
# 358/358 [==============================] - 1s 2ms/step
# patient id:  Subject14
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject15.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (11857, 6, 1)
# y_test.shape:  (11857, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject15
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 371/371 [==============================] - 1s 2ms/step
# 371/371 [==============================] - 1s 2ms/step
# patient id:  Subject15
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject16.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (11736, 6, 1)
# y_test.shape:  (11736, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject16
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 367/367 [==============================] - 1s 2ms/step
# 367/367 [==============================] - 1s 2ms/step
# patient id:  Subject16
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject17.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (11929, 6, 1)
# y_test.shape:  (11929, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject17
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 373/373 [==============================] - 1s 2ms/step
# 373/373 [==============================] - 1s 2ms/step
# patient id:  Subject17
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject18.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (11771, 6, 1)
# y_test.shape:  (11771, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject18
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 368/368 [==============================] - 1s 2ms/step
# 368/368 [==============================] - 1s 2ms/step
# patient id:  Subject18
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject19.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (11771, 6, 1)
# y_test.shape:  (11771, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject19
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 368/368 [==============================] - 1s 2ms/step
# 368/368 [==============================] - 1s 2ms/step
# patient id:  Subject19
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject1.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (8612, 6, 1)
# y_test.shape:  (8612, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject1
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 270/270 [==============================] - 1s 2ms/step
# 270/270 [==============================] - 1s 2ms/step
# patient id:  Subject1
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject20.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (11437, 6, 1)
# y_test.shape:  (11437, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject20
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 358/358 [==============================] - 1s 2ms/step
# 358/358 [==============================] - 1s 2ms/step
# patient id:  Subject20
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject21.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (11432, 6, 1)
# y_test.shape:  (11432, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject21
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 358/358 [==============================] - 1s 2ms/step
# 358/358 [==============================] - 1s 2ms/step
# patient id:  Subject21
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject22.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (11868, 6, 1)
# y_test.shape:  (11868, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject22
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 371/371 [==============================] - 1s 3ms/step
# 371/371 [==============================] - 1s 2ms/step
# patient id:  Subject22
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject23.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (11617, 6, 1)
# y_test.shape:  (11617, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject23
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 364/364 [==============================] - 1s 2ms/step
# 364/364 [==============================] - 1s 2ms/step
# patient id:  Subject23
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject24.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (9961, 6, 1)
# y_test.shape:  (9961, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject24
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 312/312 [==============================] - 1s 2ms/step
# 312/312 [==============================] - 1s 2ms/step
# patient id:  Subject24
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject25.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (11796, 6, 1)
# y_test.shape:  (11796, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject25
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 369/369 [==============================] - 1s 2ms/step
# 369/369 [==============================] - 1s 2ms/step
# patient id:  Subject25
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject26.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (11691, 6, 1)
# y_test.shape:  (11691, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject26
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 366/366 [==============================] - 1s 2ms/step
# 366/366 [==============================] - 1s 2ms/step
# patient id:  Subject26
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject27.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (11879, 6, 1)
# y_test.shape:  (11879, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject27
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 372/372 [==============================] - 1s 2ms/step
# 372/372 [==============================] - 1s 2ms/step
# patient id:  Subject27
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject28.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (11810, 6, 1)
# y_test.shape:  (11810, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject28
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 370/370 [==============================] - 1s 2ms/step
# 370/370 [==============================] - 1s 2ms/step
# patient id:  Subject28
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject29.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (6579, 6, 1)
# y_test.shape:  (6579, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject29
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 206/206 [==============================] - 1s 2ms/step
# 206/206 [==============================] - 0s 2ms/step
# patient id:  Subject29
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject2.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
# ...
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 280/280 [==============================] - 1s 3ms/step
# 280/280 [==============================] - 1s 2ms/step
# patient id:  Subject51
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject53.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (8889, 6, 1)
# y_test.shape:  (8889, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject53
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 278/278 [==============================] - 1s 3ms/step
# 278/278 [==============================] - 1s 2ms/step
# patient id:  Subject53
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject54.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (8093, 6, 1)
# y_test.shape:  (8093, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject54
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 253/253 [==============================] - 1s 3ms/step
# 253/253 [==============================] - 1s 2ms/step
# patient id:  Subject54
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject5.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (10753, 6, 1)
# y_test.shape:  (10753, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject5
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 337/337 [==============================] - 1s 2ms/step
# 337/337 [==============================] - 1s 2ms/step
# patient id:  Subject5
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject6.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (11541, 6, 1)
# y_test.shape:  (11541, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject6
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 361/361 [==============================] - 1s 2ms/step
# 361/361 [==============================] - 1s 2ms/step
# patient id:  Subject6
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject7.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (11389, 6, 1)
# y_test.shape:  (11389, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject7
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 356/356 [==============================] - 1s 2ms/step
# 356/356 [==============================] - 1s 2ms/step
# patient id:  Subject7
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject8.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (11340, 6, 1)
# y_test.shape:  (11340, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject8
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 355/355 [==============================] - 1s 2ms/step
# 355/355 [==============================] - 1s 3ms/step
# patient id:  Subject8
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_diatrend_subset\\processed_cgm_data_Subject9.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\diatrend.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_diatrend_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (11745, 6, 1)
# y_test.shape:  (11745, 1)
# x.shape =  (None, 6, 32)
# x.shape =  (None, 6, 32)
# Evaluating for patient_id: Subject9
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_diatrend_6sh\nb_future_steps_6_seed_10_\model.hdf5
# 368/368 [==============================] - 1s 2ms/step
# 368/368 [==============================] - 1s 2ms/step
# patient id:  Subject9
