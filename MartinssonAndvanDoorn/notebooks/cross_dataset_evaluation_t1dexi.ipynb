# %%
import logging
import sys
import os
import yaml
import pprint
import importlib.util
import tensorflow as tf
import itertools
import copy
import datetime
logging.basicConfig(format='%(asctime)s %(levelname)s %(message)s',
                    level=logging.DEBUG,
                    stream=sys.stdout)

import numpy as np
import metrics
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt

# %%
# Look at the output of ohio data loader
import xml.etree.ElementTree as ET
import pandas as pd
import numpy as np
import utils
import os
import glob

def load_module(script_path):
    spec = importlib.util.spec_from_file_location("module.name", script_path)
    module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(module)
    return module

def load_cfg(yaml_filepath):
    """
    Load a YAML configuration file.

    Parameters
    ----------
    yaml_filepath : str

    Returns
    -------
    cfg : dict
    """
    # Read YAML experiment definition file
    with open(yaml_filepath, 'r') as stream:
        cfg = yaml.load(stream)
    cfg = make_paths_absolute(os.path.dirname(yaml_filepath), cfg)
    return cfg

def load_cfgs(yaml_filepath):
    """
    Load YAML configuration files.

    Parameters
    ----------
    yaml_filepath : str

    Returns
    -------
    cfgs : [dict]
    """
    # Read YAML experiment definition file
    with open(yaml_filepath, 'r') as stream:
        cfg = yaml.load(stream, Loader=yaml.SafeLoader)

    cfg = make_paths_absolute(os.path.dirname(yaml_filepath), cfg)

    hyperparameters = []
    hyperparameter_names = []
    hyperparameter_values = []
    # TODO: ugly, should handle arbitrary depth
    for k1 in cfg.keys():
        for k2 in cfg[k1].keys():
            if k2.startswith("param_"):
                hyperparameters.append((k1, k2))
                hyperparameter_names.append((k1, k2[6:]))
                hyperparameter_values.append(cfg[k1][k2])

    hyperparameter_valuess = itertools.product(*hyperparameter_values)


    artifacts_path = cfg['train']['artifacts_path']

    cfgs = []
    for hyperparameter_values in hyperparameter_valuess:
        configuration_name = ""
        for ((k1, k2), value) in zip(hyperparameter_names, hyperparameter_values):
            #print(k1, k2, value)
            cfg[k1][k2] = value
            configuration_name += "{}_{}_".format(k2, str(value))

        cfg['train']['artifacts_path'] = os.path.join(artifacts_path, configuration_name)

        cfgs.append(copy.deepcopy(cfg))

    return cfgs



def make_paths_absolute(dir_, cfg):
    """
    Make all values for keys ending with `_path` absolute to dir_.

    Parameters
    ----------
    dir_ : str
    cfg : dict

    Returns
    -------
    cfg : dict
    """
    for key in cfg.keys():
        if key.endswith("_path"):
            cfg[key] = os.path.join(dir_, cfg[key])
            cfg[key] = os.path.abspath(cfg[key])
            if not os.path.exists(cfg[key]):
                logging.error("%s does not exist.", cfg[key])
        if type(cfg[key]) is dict:
            cfg[key] = make_paths_absolute(dir_, cfg[key])
    return cfg

# %%
def evaluate(model, x_test, y_test, cfg):
    if 'csv_path' in cfg['dataset']:
        basename = os.path.basename(cfg['dataset']['csv_path'])
        patient_id = basename.split('-')[0]
    else:
        patient_id = ""
    if 'scale' in cfg['dataset']:
        scale = float(cfg['dataset']['scale'])
    else:
        scale = 1.0

    # load the trained weights
    weights_path = os.path.join(cfg['train']['artifacts_path'], "model.hdf5")
    print("loading weights: {}".format(weights_path))
    model.load_weights(weights_path)

    y_pred = model.predict(x_test)[:,1].flatten()/scale
    y_std  = model.predict(x_test)[:,0].flatten()/scale
    y_test = y_test.flatten()/scale
    t0 = x_test[:,-1,0]/scale

    rmse = metrics.root_mean_squared_error(y_test, y_pred)
    print("patient id: ", patient_id)
    with open(os.path.join(cfg['train']['artifacts_path'], "{}_rmse.txt".format(patient_id)), "w") as outfile:
        outfile.write("{}\n".format(rmse))
    
    # Calculate MAE
    mae = np.mean(np.abs(y_test - y_pred))
    with open(os.path.join(cfg['train']['artifacts_path'], "{}_mae.txt".format(patient_id)), "w") as outfile:
        outfile.write("{}\n".format(mae))

    # Calculate MSE
    # mse = np.mean((y_test - y_pred) ** 2)
    # with open(os.path.join(cfg['train']['artifacts_path'], "{}_mse.txt".format(patient_id)), "w") as outfile:
    #     outfile.write("{}\n".format(mse))

    # Calculate MAPE
    mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100  # Multiply by 100 for percentage
    with open(os.path.join(cfg['train']['artifacts_path'], "{}_mape.txt".format(patient_id)), "w") as outfile:
        outfile.write("{}\n".format(mape))

    # rmse = metrics.root_mean_squared_error(y_test, y_pred)
    # print("patient id: ", patient_id)
    # with open(os.path.join(cfg['train']['artifacts_path'], "{}_rmse.txt".format(patient_id)), "w") as outfile:
    #     outfile.write("{}\n".format(rmse))

    # seg = metrics.surveillance_error(y_test, y_pred)
    # with open(os.path.join(cfg['train']['artifacts_path'], "{}_seg.txt".format(patient_id)), "w") as outfile:
    #     outfile.write("{}\n".format(seg))

    # t0_rmse = metrics.root_mean_squared_error(y_test, t0)
    # with open(os.path.join(cfg['train']['artifacts_path'], "{}_t0_rmse.txt".format(patient_id)), "w") as outfile:
    #     outfile.write("{}\n".format(t0_rmse))

    # t0_seg = metrics.surveillance_error(y_test, t0)
    # with open(os.path.join(cfg['train']['artifacts_path'], "{}_t0_seg.txt".format(patient_id)), "w") as outfile:
    #     outfile.write("{}\n".format(t0_seg))

    # with open(os.path.join(cfg['train']['artifacts_path'], "{}_mean_std.txt".format(patient_id)), "w") as outfile:
    #     outfile.write("{}\n".format(np.mean(y_std)))

    # print("RMSE: ", rmse)
    # print("t0 RMSE: ", t0_rmse)
    # print("SEG: ", seg)
    # print("t0 SEG: ", t0_seg)

def train(model, module_train, x_train, y_train, x_valid, y_valid, cfg):
    model = module_train.train(
        model          = model,
        x_train        = x_train,
        y_train        = y_train,
        x_valid        = x_valid,
        y_valid        = y_valid,
        batch_size     = int(cfg['train']['batch_size']),
        epochs         = int(cfg['train']['epochs']),
        patience       = int(cfg['train']['patience']),
        shuffle        = cfg['train']['shuffle'],
        artifacts_path = cfg['train']['artifacts_path']
    )

    return model

def plot_target_distribution(y_test, cfg):
    if 'csv_path' in cfg['dataset']:
        basename = os.path.basename(cfg['dataset']['csv_path'])
        patient_id = basename.split('-')[0]
    else:
        patient_id = ""
    if 'scale' in cfg['dataset']:
        scale = float(cfg['dataset']['scale'])
    else:
        scale = 1.0

    plt.figure()
    sns.distplot(y_test.flatten()/scale, kde=False, norm_hist=True)
    save_path = os.path.join(cfg['train']['artifacts_path'], "{}_dist_plot.pdf".format(patient_id))
    print("saving plot to: ", save_path)
    plt.savefig(save_path, dpi=300)

def plot_nll(model, x_test, y_test, cfg):
    if 'csv_path' in cfg['dataset']:
        basename = os.path.basename(cfg['dataset']['csv_path'])
        patient_id = basename.split('-')[0]
    else:
        patient_id = ""
    if 'scale' in cfg['dataset']:
        scale = float(cfg['dataset']['scale'])
    else:
        scale = 1.0

    # load the trained weights
    model.load_weights(os.path.join(cfg['train']['artifacts_path'], "model.hdf5"))

    #day = (24*60//5)
    start_index = 0
    hours = 8
    to_plot=hours*12
    ticks_per_hour = 12
    ticks = [i*ticks_per_hour for i in range(hours+1)]
    ticks_labels = [str(i) for i in range(hours+1)]

    y_pred      = model.predict(x_test)

    for i in range(5):
        start_index = i*to_plot
        y_pred_std  = y_pred[:,0][start_index:start_index+to_plot]/scale
        y_pred_mean = y_pred[:,1][start_index:start_index+to_plot]/scale
        y_true      = y_test[:,0][start_index:start_index+to_plot]/scale

        xs = np.arange(len(y_true))
        plt.clf()
        plt.ylim([0, 400])
        #plt.ylim([-2, 2])
        plt.plot(xs, y_true, label='ground truth', linestyle='--')
        plt.plot(xs, y_pred_mean, label='prediction')
        plt.fill_between(xs, y_pred_mean-y_pred_std, y_pred_mean+y_pred_std,
                alpha=0.5, edgecolor='#CC4F1B', facecolor='#FF9848')
        plt.xlabel("Time [h]")
        plt.ylabel("Glucose Concentration [mg/dl]")
        plt.legend(loc='upper right')
        #plt.xlabel("y")
        #plt.ylabel("x")
        plt.xticks(ticks, ticks_labels)
        save_path = os.path.join(cfg['train']['artifacts_path'], "{}_nll_plot_{}.pdf".format(patient_id, i))
        print("saving plot to: ", save_path)
        plt.savefig(save_path, dpi=300)

def plot_noise_experiment(model, x_test, y_test, cfg):
    # load the trained weights
    model.load_weights(os.path.join(cfg['train']['artifacts_path'], "model.hdf5"))

    #day = (24*60//5)
    start_index = 0
    hours = 8
    to_plot=hours*12
    ticks_per_hour = 12
    ticks = [i*ticks_per_hour for i in range(hours+1)]
    ticks_labels = [str(i) for i in range(hours+1)]

    y_pred      = model.predict(x_test)

    start_index = 0
    y_pred_std  = y_pred[:,0][start_index:start_index+to_plot]
    y_pred_mean = y_pred[:,1][start_index:start_index+to_plot]
    y_true      = y_test[:,0][start_index:start_index+to_plot]

    xs = np.arange(len(y_true))
    plt.clf()
    #plt.ylim([0, 400])
    plt.ylim([-3, 3])
    plt.plot(xs, y_true, label='ground truth', linestyle='--')
    plt.plot(xs, y_pred_mean, label='prediction')
    plt.fill_between(xs, y_pred_mean-y_pred_std, y_pred_mean+y_pred_std,
            alpha=0.5, edgecolor='#CC4F1B', facecolor='#FF9848')
    #plt.xlabel("Time [h]")
    #plt.ylabel("Glucose Concentration [mg/dl]")
    plt.legend(loc='upper right')
    plt.xlabel("x")
    plt.ylabel("y")
    plt.xticks(ticks, ticks_labels)
    save_path = os.path.join(cfg['train']['artifacts_path'], "noise_experiment_plot.pdf")
    print("saving plot to: ", save_path)
    plt.savefig(save_path, dpi=300)



def plot_seg(model, x_test, y_test, cfg):
    if 'csv_path' in cfg['dataset']:
        basename = os.path.basename(cfg['dataset']['csv_path'])
        patient_id = basename.split('-')[0]
    else:
        patient_id = ""
    if 'scale' in cfg['dataset']:
        scale = float(cfg['dataset']['scale'])
    else:
        scale = 1.0

    # load the trained weights
    model.load_weights(os.path.join(cfg['train']['artifacts_path'], "model.hdf5"))

    y_pred      = model.predict(x_test)
    y_pred_std  = y_pred[:,0][:]/scale
    y_pred_mean = y_pred[:,1][:]/scale
    y_true      = y_test[:,0][:]/scale

    data = np.loadtxt('seg.csv')

    fig, ax = plt.subplots()
    ax.set_title('Patient {} SEG'.format(patient_id))
    ax.set_xlabel('Reference Concentration [mg/dl]')
    ax.set_ylabel('Predicted Concentration [mg/dl]')
    cax = ax.imshow(np.transpose(data), origin='lower', interpolation='nearest')
    cbar = fig.colorbar(cax, ticks=[0.25, 1.0, 2.0, 3.0, 3.75], orientation='vertical')
    cbar.ax.set_yticklabels(['None', 'Mild', 'Moderate', 'High', 'Extreme'],
            rotation=90, va='center')

    plt.scatter(y_true, y_pred_mean, s=25, facecolors='white', edgecolors='black')

    save_path = os.path.join(cfg['train']['artifacts_path'], "{}_seg_plot.pdf".format(patient_id))
    print("saving plot to: ", save_path)
    plt.savefig(save_path, dpi=300)

# %%
yaml_files = glob.glob(f"./cross_check_vandoorn_t1dexi_30min/*.yaml")
mode = "evaluate"

# %%
yaml_files
# Out:
# ['./cross_check_vandoorn_t1dexi_30min\\1010_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1015_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\103_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1043_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1082_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1115_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1121_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1127_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1139_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1143_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\114_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\115_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1171_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1194_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\11_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1201_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1205_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1211_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1219_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1230_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1239_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1271_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1286_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1311_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1330_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1336_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1343_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1345_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1348_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1361_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1362_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1363_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1377_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1381_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1386_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1408_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1422_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1427_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1433_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1435_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\144_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1457_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1459_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1484_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1503_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\152_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1554_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1558_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1636_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1650_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1683_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1689_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1695_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1722_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1726_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\173_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\187_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\18_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\1_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\248_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\24_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\252_evaluation.yaml',
#  './cross_check_vandoorn_t1dexi_30min\\25_evaluation.yaml']

# %%
for yaml_fp in yaml_files:
    cfgs = load_cfgs(yaml_fp)
    print("Running {} experiments.".format(len(cfgs)))
    for cfg in cfgs:
        seed = int(cfg['train']['seed'])
        np.random.seed(seed)

        # Print the configuration - just to make sure that you loaded what you
        # wanted to load

        module_dataset       = load_module(cfg['dataset']['script_path'])
        module_model         = load_module(cfg['model']['script_path'])
        module_optimizer     = load_module(cfg['optimizer']['script_path'])
        module_loss_function = load_module(cfg['loss_function']['script_path'])
        module_train         = load_module(cfg['train']['script_path'])

        pp = pprint.PrettyPrinter(indent=4)
        pp.pprint(cfg)

        #print("loading dataset ...")
        #nb_past_steps = cfg['dataset']['nb_past_steps']
        #nb_past_steps_tmp = 36
        #cfg['dataset']['nb_past_steps'] = nb_past_steps_tmp
        x_train, y_train, x_valid, y_valid, x_test, y_test = module_dataset.load_dataset(cfg['dataset'])
        #x_train = x_train[:,-nb_past_steps:,:]
        #x_valid = x_valid[:,-nb_past_steps:,:]
        #x_test = x_test[:,-nb_past_steps:,:]
        print("x_train.shape: ", x_train.shape)
        print("y_train.shape: ", y_train.shape)
        print("x_valid.shape: ", x_valid.shape)
        print("y_valid.shape: ", y_valid.shape)
        print("x_test.shape: ", x_test.shape)
        print("y_test.shape: ", y_test.shape)
        #print("loading optimizer ...")
        optimizer = module_optimizer.load(cfg['optimizer'])

        #print("loading loss function ...")
        loss_function = module_loss_function.load()
        #print("loaded function {} ...".format(loss_function.__name__))

        #print("loading model ...")
        if 'tf_nll' in loss_function.__name__:
            model = module_model.load(
                x_train.shape[1:],
                y_train.shape[1]*2,
                cfg['model']
            )
        else:
            model = module_model.load(
                x_train.shape[1:],
                y_train.shape[1],
                cfg['model']
            )

        if 'initial_weights_path' in cfg['train']:
            #print("Loading initial weights: ", cfg['train']['initial_weights_path'])
            model.load_weights(cfg['train']['initial_weights_path'])

        model.compile(
            optimizer=optimizer,
            loss=loss_function
        )

        #print(model.summary())

        # training mode
        if mode == 'train':
            #print("training model ...")
            train(model, module_train, x_train, y_train, x_valid, y_valid, cfg)
        if mode == 'plot_nll':
            plot_nll(model, x_test, y_test, cfg)
        if mode == 'plot_noise_experiment':
            plot_noise_experiment(model, x_test, y_test, cfg)
        if mode == 'plot_seg':
            plot_seg(model, x_test, y_test, cfg)
        if mode == 'plot_dist':
            plot_target_distribution(y_test, cfg)

        # evaluation mode
        if mode == 'evaluate':
            evaluate(model, x_test, y_test, cfg)
# Out:
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_t1dexi_subset\\T1DEXI_cgm_processed\\1010.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\t1dexi.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_t1dexi_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# nb_future_steps  6
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (7552, 6, 1)
# y_test.shape:  (7552, 1)
# WARNING:tensorflow:Layer lstm_63 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:09:04,224 WARNING Layer lstm_63 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# x.shape =  (?, 6, 32)
# x.shape =  (?, 6, 32)
# WARNING:tensorflow:Layer lstm_64 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:09:04,357 WARNING Layer lstm_64 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_t1dexi_6sh\nb_future_steps_6_seed_10_\model.hdf5
# C:\Users\baiyi\AppData\Roaming\Python\Python310\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# patient id:  1010.csv
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_t1dexi_subset\\T1DEXI_cgm_processed\\1015.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\t1dexi.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_t1dexi_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# nb_future_steps  6
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (6173, 6, 1)
# y_test.shape:  (6173, 1)
# WARNING:tensorflow:Layer lstm_65 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:09:16,669 WARNING Layer lstm_65 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# x.shape =  (?, 6, 32)
# x.shape =  (?, 6, 32)
# WARNING:tensorflow:Layer lstm_66 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:09:16,732 WARNING Layer lstm_66 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_t1dexi_6sh\nb_future_steps_6_seed_10_\model.hdf5
# C:\Users\baiyi\AppData\Roaming\Python\Python310\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# patient id:  1015.csv
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_t1dexi_subset\\T1DEXI_cgm_processed\\103.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\t1dexi.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_t1dexi_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# nb_future_steps  6
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (5701, 6, 1)
# y_test.shape:  (5701, 1)
# WARNING:tensorflow:Layer lstm_67 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:09:20,650 WARNING Layer lstm_67 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# x.shape =  (?, 6, 32)
# x.shape =  (?, 6, 32)
# WARNING:tensorflow:Layer lstm_68 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:09:20,717 WARNING Layer lstm_68 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_t1dexi_6sh\nb_future_steps_6_seed_10_\model.hdf5
# C:\Users\baiyi\AppData\Roaming\Python\Python310\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# patient id:  103.csv
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_t1dexi_subset\\T1DEXI_cgm_processed\\1043.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\t1dexi.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_t1dexi_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# nb_future_steps  6
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (7807, 6, 1)
# y_test.shape:  (7807, 1)
# WARNING:tensorflow:Layer lstm_69 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:09:24,618 WARNING Layer lstm_69 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# x.shape =  (?, 6, 32)
# x.shape =  (?, 6, 32)
# WARNING:tensorflow:Layer lstm_70 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:09:24,672 WARNING Layer lstm_70 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_t1dexi_6sh\nb_future_steps_6_seed_10_\model.hdf5
# C:\Users\baiyi\AppData\Roaming\Python\Python310\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# patient id:  1043.csv
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_t1dexi_subset\\T1DEXI_cgm_processed\\1082.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\t1dexi.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_t1dexi_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# nb_future_steps  6
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (7890, 6, 1)
# y_test.shape:  (7890, 1)
# WARNING:tensorflow:Layer lstm_71 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:09:29,075 WARNING Layer lstm_71 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# x.shape =  (?, 6, 32)
# x.shape =  (?, 6, 32)
# WARNING:tensorflow:Layer lstm_72 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:09:29,116 WARNING Layer lstm_72 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_t1dexi_6sh\nb_future_steps_6_seed_10_\model.hdf5
# C:\Users\baiyi\AppData\Roaming\Python\Python310\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# patient id:  1082.csv
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_t1dexi_subset\\T1DEXI_cgm_processed\\1115.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\t1dexi.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_t1dexi_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# nb_future_steps  6
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (7827, 6, 1)
# y_test.shape:  (7827, 1)
# WARNING:tensorflow:Layer lstm_73 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:09:33,554 WARNING Layer lstm_73 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# x.shape =  (?, 6, 32)
# x.shape =  (?, 6, 32)
# WARNING:tensorflow:Layer lstm_74 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:09:33,604 WARNING Layer lstm_74 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_t1dexi_6sh\nb_future_steps_6_seed_10_\model.hdf5
# C:\Users\baiyi\AppData\Roaming\Python\Python310\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# patient id:  1115.csv
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_t1dexi_subset\\T1DEXI_cgm_processed\\1121.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\t1dexi.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_t1dexi_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# nb_future_steps  6
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (7880, 6, 1)
# y_test.shape:  (7880, 1)
# WARNING:tensorflow:Layer lstm_75 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:09:38,630 WARNING Layer lstm_75 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# x.shape =  (?, 6, 32)
# x.shape =  (?, 6, 32)
# WARNING:tensorflow:Layer lstm_76 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:09:38,688 WARNING Layer lstm_76 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_t1dexi_6sh\nb_future_steps_6_seed_10_\model.hdf5
# C:\Users\baiyi\AppData\Roaming\Python\Python310\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# patient id:  1121.csv
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_t1dexi_subset\\T1DEXI_cgm_processed\\1127.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\t1dexi.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_t1dexi_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# nb_future_steps  6
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (7091, 6, 1)
# y_test.shape:  (7091, 1)
# WARNING:tensorflow:Layer lstm_77 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:09:43,184 WARNING Layer lstm_77 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# x.shape =  (?, 6, 32)
# x.shape =  (?, 6, 32)
# WARNING:tensorflow:Layer lstm_78 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:09:43,238 WARNING Layer lstm_78 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_t1dexi_6sh\nb_future_steps_6_seed_10_\model.hdf5
# C:\Users\baiyi\AppData\Roaming\Python\Python310\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# patient id:  1127.csv
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_t1dexi_subset\\T1DEXI_cgm_processed\\1139.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\t1dexi.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_t1dexi_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# nb_future_steps  6
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (5447, 6, 1)
# y_test.shape:  (5447, 1)
# WARNING:tensorflow:Layer lstm_79 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:09:47,232 WARNING Layer lstm_79 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# x.shape =  (?, 6, 32)
# x.shape =  (?, 6, 32)
# WARNING:tensorflow:Layer lstm_80 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:09:47,280 WARNING Layer lstm_80 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_t1dexi_6sh\nb_future_steps_6_seed_10_\model.hdf5
# C:\Users\baiyi\AppData\Roaming\Python\Python310\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# patient id:  1139.csv
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_t1dexi_subset\\T1DEXI_cgm_processed\\1143.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\t1dexi.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_t1dexi_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# nb_future_steps  6
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (7667, 6, 1)
# y_test.shape:  (7667, 1)
# WARNING:tensorflow:Layer lstm_81 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:09:51,187 WARNING Layer lstm_81 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# x.shape =  (?, 6, 32)
# x.shape =  (?, 6, 32)
# WARNING:tensorflow:Layer lstm_82 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:09:51,238 WARNING Layer lstm_82 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_t1dexi_6sh\nb_future_steps_6_seed_10_\model.hdf5
# C:\Users\baiyi\AppData\Roaming\Python\Python310\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# patient id:  1143.csv
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_t1dexi_subset\\T1DEXI_cgm_processed\\114.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\t1dexi.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_t1dexi_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# nb_future_steps  6
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (7700, 6, 1)
# y_test.shape:  (7700, 1)
# WARNING:tensorflow:Layer lstm_83 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:09:55,668 WARNING Layer lstm_83 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# x.shape =  (?, 6, 32)
# x.shape =  (?, 6, 32)
# WARNING:tensorflow:Layer lstm_84 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:09:55,716 WARNING Layer lstm_84 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_t1dexi_6sh\nb_future_steps_6_seed_10_\model.hdf5
# C:\Users\baiyi\AppData\Roaming\Python\Python310\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# patient id:  114.csv
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_t1dexi_subset\\T1DEXI_cgm_processed\\115.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\t1dexi.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_t1dexi_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# nb_future_steps  6
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (7931, 6, 1)
# y_test.shape:  (7931, 1)
# WARNING:tensorflow:Layer lstm_85 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:10:00,374 WARNING Layer lstm_85 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# x.shape =  (?, 6, 32)
# x.shape =  (?, 6, 32)
# WARNING:tensorflow:Layer lstm_86 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:10:00,419 WARNING Layer lstm_86 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_t1dexi_6sh\nb_future_steps_6_seed_10_\model.hdf5
# C:\Users\baiyi\AppData\Roaming\Python\Python310\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# patient id:  115.csv
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_t1dexi_subset\\T1DEXI_cgm_processed\\1171.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\t1dexi.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_t1dexi_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# nb_future_steps  6
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (7816, 6, 1)
# y_test.shape:  (7816, 1)
# WARNING:tensorflow:Layer lstm_87 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:10:05,111 WARNING Layer lstm_87 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# x.shape =  (?, 6, 32)
# x.shape =  (?, 6, 32)
# WARNING:tensorflow:Layer lstm_88 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:10:05,159 WARNING Layer lstm_88 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_t1dexi_6sh\nb_future_steps_6_seed_10_\model.hdf5
# C:\Users\baiyi\AppData\Roaming\Python\Python310\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# patient id:  1171.csv
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_t1dexi_subset\\T1DEXI_cgm_processed\\1194.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\t1dexi.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_t1dexi_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# nb_future_steps  6
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (7959, 6, 1)
# y_test.shape:  (7959, 1)
# WARNING:tensorflow:Layer lstm_89 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:10:09,819 WARNING Layer lstm_89 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# x.shape =  (?, 6, 32)
# x.shape =  (?, 6, 32)
# WARNING:tensorflow:Layer lstm_90 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:10:09,887 WARNING Layer lstm_90 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_t1dexi_6sh\nb_future_steps_6_seed_10_\model.hdf5
# C:\Users\baiyi\AppData\Roaming\Python\Python310\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# patient id:  1194.csv
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_t1dexi_subset\\T1DEXI_cgm_processed\\11.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\t1dexi.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_t1dexi_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# nb_future_steps  6
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (7970, 6, 1)
# y_test.shape:  (7970, 1)
# WARNING:tensorflow:Layer lstm_91 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:10:14,740 WARNING Layer lstm_91 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# x.shape =  (?, 6, 32)
# x.shape =  (?, 6, 32)
# WARNING:tensorflow:Layer lstm_92 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:10:14,792 WARNING Layer lstm_92 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_t1dexi_6sh\nb_future_steps_6_seed_10_\model.hdf5
# C:\Users\baiyi\AppData\Roaming\Python\Python310\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# patient id:  11.csv
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_t1dexi_subset\\T1DEXI_cgm_processed\\1201.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\t1dexi.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_t1dexi_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# nb_future_steps  6
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (7893, 6, 1)
# y_test.shape:  (7893, 1)
# WARNING:tensorflow:Layer lstm_93 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# ...
# 2025-02-04 21:14:04,912 WARNING Layer lstm_178 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_t1dexi_6sh\nb_future_steps_6_seed_10_\model.hdf5
# C:\Users\baiyi\AppData\Roaming\Python\Python310\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# patient id:  18.csv
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_t1dexi_subset\\T1DEXI_cgm_processed\\1.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\t1dexi.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_t1dexi_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# nb_future_steps  6
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (7799, 6, 1)
# y_test.shape:  (7799, 1)
# WARNING:tensorflow:Layer lstm_179 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:14:11,347 WARNING Layer lstm_179 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# x.shape =  (?, 6, 32)
# x.shape =  (?, 6, 32)
# WARNING:tensorflow:Layer lstm_180 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:14:11,399 WARNING Layer lstm_180 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_t1dexi_6sh\nb_future_steps_6_seed_10_\model.hdf5
# C:\Users\baiyi\AppData\Roaming\Python\Python310\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# patient id:  1.csv
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_t1dexi_subset\\T1DEXI_cgm_processed\\248.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\t1dexi.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_t1dexi_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# nb_future_steps  6
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (5698, 6, 1)
# y_test.shape:  (5698, 1)
# WARNING:tensorflow:Layer lstm_181 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:14:17,570 WARNING Layer lstm_181 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# x.shape =  (?, 6, 32)
# x.shape =  (?, 6, 32)
# WARNING:tensorflow:Layer lstm_182 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:14:17,620 WARNING Layer lstm_182 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_t1dexi_6sh\nb_future_steps_6_seed_10_\model.hdf5
# C:\Users\baiyi\AppData\Roaming\Python\Python310\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# patient id:  248.csv
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_t1dexi_subset\\T1DEXI_cgm_processed\\24.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\t1dexi.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_t1dexi_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# nb_future_steps  6
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (7684, 6, 1)
# y_test.shape:  (7684, 1)
# WARNING:tensorflow:Layer lstm_183 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:14:23,368 WARNING Layer lstm_183 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# x.shape =  (?, 6, 32)
# x.shape =  (?, 6, 32)
# WARNING:tensorflow:Layer lstm_184 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:14:23,419 WARNING Layer lstm_184 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_t1dexi_6sh\nb_future_steps_6_seed_10_\model.hdf5
# C:\Users\baiyi\AppData\Roaming\Python\Python310\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# patient id:  24.csv
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_t1dexi_subset\\T1DEXI_cgm_processed\\252.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\t1dexi.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_t1dexi_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# nb_future_steps  6
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (7399, 6, 1)
# y_test.shape:  (7399, 1)
# WARNING:tensorflow:Layer lstm_185 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:14:29,656 WARNING Layer lstm_185 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# x.shape =  (?, 6, 32)
# x.shape =  (?, 6, 32)
# WARNING:tensorflow:Layer lstm_186 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:14:29,709 WARNING Layer lstm_186 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_t1dexi_6sh\nb_future_steps_6_seed_10_\model.hdf5
# C:\Users\baiyi\AppData\Roaming\Python\Python310\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# patient id:  252.csv
# Running 1 experiments.
# {   'dataset': {   'csv_path': 'C:\\Users\\baiyi\\OneDrive\\Desktop\\Modify_GenBG\\modified_t1dexi_subset\\T1DEXI_cgm_processed\\25.csv',
#                    'nb_future_steps': 6,
#                    'nb_past_steps': 6,
#                    'param_nb_future_steps': [6],
#                    'scale': 0.01,
#                    'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\datasets\\t1dexi.py',
#                    'test_fraction': 1.0,
#                    'train_fraction': 0.0,
#                    'valid_fraction': 0.0},
#     'loss_function': {   'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\loss_functions\\mse_keras.py'},
#     'model': {   'activation_function': 'relu',
#                  'nb_lstm_states': 32,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\models\\lstm_experiment_keras_vanDoorn.py'},
#     'optimizer': {   'learning_rate': 0.0001,
#                      'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\optimizers\\adam_keras.py'},
#     'train': {   'artifacts_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\artifacts\\cross_check_vandoorn_t1dexi_6sh\\nb_future_steps_6_seed_10_',
#                  'batch_size': 1024,
#                  'epochs': 10000,
#                  'param_seed': [10],
#                  'patience': 100,
#                  'script_path': 'c:\\Users\\baiyi\\OneDrive\\Desktop\\ReproGenBG_ML4H\\MartinssonAndvanDoorn\\train\\train_keras.py',
#                  'seed': 10,
#                  'shuffle': True}}
# nb_future_steps  6
# x_train.shape:  (0, 6, 1)
# y_train.shape:  (0, 1)
# x_valid.shape:  (0, 6, 1)
# y_valid.shape:  (0, 1)
# x_test.shape:  (7443, 6, 1)
# y_test.shape:  (7443, 1)
# WARNING:tensorflow:Layer lstm_187 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:14:35,961 WARNING Layer lstm_187 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# x.shape =  (?, 6, 32)
# x.shape =  (?, 6, 32)
# WARNING:tensorflow:Layer lstm_188 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-02-04 21:14:36,012 WARNING Layer lstm_188 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# loading weights: c:\Users\baiyi\OneDrive\Desktop\ReproGenBG_ML4H\MartinssonAndvanDoorn\artifacts\cross_check_vandoorn_t1dexi_6sh\nb_future_steps_6_seed_10_\model.hdf5
# C:\Users\baiyi\AppData\Roaming\Python\Python310\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# patient id:  25.csv
