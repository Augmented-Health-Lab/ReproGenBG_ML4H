# %%
import argparse
import json
import os
import pandas as pd
import os

import datetime
import numpy as np
from cgms_data_seg_diatrend import CGMSDataSeg
from cnn_ohio import regressor, regressor_transfer, test_ckpt
from data_reader_DiaTrend import DataReader

import tensorflow as tf

# New method in TensorFlow 2.x:
# This will list the devices TensorFlow recognizes
print("TensorFlow version:", tf.__version__)
print("List of devices available to TensorFlow:")
print(tf.config.list_physical_devices())
# Out:
# TensorFlow version: 2.10.1
# List of devices available to TensorFlow:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
def preprocess_DiaTrend(path):

    subject = pd.read_csv(path)
    subject['date'] = pd.to_datetime(subject['date'], errors='coerce')  # Convert 'date' column to datetime if not already
    print(subject['date'][0])
    subject.sort_values('date', inplace=True)  # Sort the DataFrame by the 'date' column

    # Assuming self.interval_timedelta is set, for example:
    interval_timedelta = datetime.timedelta(minutes=6)  # Example timedelta of 6 minutes, providing a range for latency

    # Create a list to store the results
    res = []

    # Initialize the first group
    if not subject.empty:
        current_group = [subject.iloc[0]['mg/dl']]
        last_time = subject.iloc[0]['date']

    # Iterate over rows in DataFrame starting from the second row
    for index, row in subject.iloc[1:].iterrows():
        current_time = row['date']
        if (current_time - last_time) <= interval_timedelta:
            # If the time difference is within the limit, add to the current group
            current_group.append(row['mg/dl'])
        else:
            # Otherwise, start a new group
            res.append(current_group)
            current_group = [row['mg/dl']]
        last_time = current_time

    # Add the last group if it's not empty
    if current_group:
        res.append(current_group)
    
    # Filter out groups with fewer than 10 glucose readings
    # res = [group for group in res if len(group) >= 10]

    return res

# %% [markdown]
# # The entire loop

# %%
epoch = 80
ph = 6
path = "../diatrend_results"
# Correct path with raw string
for sh in [6, 12, 18, 24]:
    for fold_num in range(1, 6):
        train_directory_path = f'C:/Users/baiyi/OneDrive/Desktop/Modify_GenBG/modified_diatrend_subset/fold{fold_num}_training'
        # List files without their extensions
        train_file_names = [os.path.splitext(file)[0] for file in os.listdir(train_directory_path)
                            if os.path.isfile(os.path.join(train_directory_path, file))]
        cleaned_subjects = [s.replace("processed_cgm_data_", "") for s in train_file_names]


        # Define the directory path
        test_directory_path = f'C:/Users/baiyi/OneDrive/Desktop/Modify_GenBG/modified_diatrend_subset/fold{fold_num}_test'  # Use a raw string for paths on Windows
        # List files without their extensions
        test_file_names = [os.path.splitext(file)[0] for file in os.listdir(test_directory_path)
                    if os.path.isfile(os.path.join(test_directory_path, file))]
        cleaned_test_subjects = [s.replace("processed_cgm_data_", "") for s in test_file_names]

        train_data = dict()
        for subj in train_file_names:

            subj_path = f'C:/Users/baiyi/OneDrive/Desktop/Modify_GenBG/modified_diatrend_subset/fold{fold_num}_training/{subj}.csv'
            reader = preprocess_DiaTrend(subj_path)
            train_data[subj] = reader

        test_data = dict()
        for subj in test_file_names:

            subj_path = f'C:/Users/baiyi/OneDrive/Desktop/Modify_GenBG/modified_diatrend_subset/fold{fold_num}_test/{subj}.csv'
            reader = preprocess_DiaTrend(subj_path)
            test_data[subj] = reader

        # a dumb dataset instance 
        train_dataset = CGMSDataSeg(
            "diatrend", "C:/Users/baiyi/OneDrive/Desktop/Modify_GenBG/modified_diatrend_subset/fold1_training/processed_cgm_data_Subject12.csv", 5
        )
        sampling_horizon = sh
        prediction_horizon = ph
        scale = 0.01
        outtype = "Same"
        # train on training dataset
        # k_size, nblock, nn_size, nn_layer, learning_rate, batch_size, epoch, beta
        with open(f'../diatrend_results/config.json') as json_file:
            config = json.load(json_file)
        argv = (
            config["k_size"],
            config["nblock"],
            config["nn_size"],
            config["nn_layer"],
            config["learning_rate"],
            config["batch_size"],
            epoch,
            config["beta"],
        )
        l_type = config["loss"]
        # test on patients data
        outdir = os.path.join(path, f"ph_{prediction_horizon}_sh{sampling_horizon}_fold{fold_num}_{l_type}")
        if not os.path.exists(outdir):
            os.makedirs(outdir)
        all_errs = []

        # Train on the training fold
        cleaned_subjects.sort()
        standard = False  

        train_pids = set(cleaned_subjects)
        local_train_data = []
        for k in train_pids:
            local_train_data += train_data["processed_cgm_data_" + k]


        train_dataset.data = local_train_data
        train_dataset.set_cutpoint = -1
        train_dataset.reset(
            sampling_horizon,
            prediction_horizon,
            scale,
            100,
            False,
            outtype,
            1,
            standard,
        )
        regressor(train_dataset, *argv, l_type, outdir)

        # Evaluate on the test patients
        all_errs = []
        for pid in cleaned_test_subjects: # First 9 as subset, can be an example
            # Fine-tune and test
            target_test_dataset = CGMSDataSeg(
            "diatrend", f"C:/Users/baiyi/OneDrive/Desktop/Modify_GenBG/modified_diatrend_subset/fold{fold_num}_test/processed_cgm_data_{pid}.csv", 5
            )
            target_test_dataset.set_cutpoint = 1
            target_test_dataset.reset(
                sampling_horizon,
                prediction_horizon,
                scale,
                0.01,
                False,
                outtype,
                1,
                standard,
            )

            err, labels = test_ckpt(target_test_dataset, outdir)
            np.savetxt(
                f"{outdir}/{pid}.txt",
                [err],
                fmt="%.4f",
            )
            all_errs.append([str(pid), err]) 
        all_errs = np.array(all_errs, dtype=object)  # Use dtype=object to handle mixed types
        np.savetxt(f"{outdir}/errors.txt", all_errs, fmt="%s %.4f")
        # label pair:(groundTruth, y_pred)
# Out:
# 2019-06-09 00:04:51
# 2019-06-04 02:21:39
# 2019-09-05 00:01:34
# 2019-10-02 00:01:19
# 2019-12-25 00:02:52
# 2020-01-01 00:03:08
# 2019-11-24 00:04:24
# 2020-04-09 00:00:29
# 2020-05-14 00:00:34
# 2021-02-14 00:04:12
# 2020-09-16 00:03:53
# 2020-06-26 00:03:03
# 2021-03-14 00:02:30
# 2021-06-30 00:00:12
# 2021-02-26 00:03:54
# 2021-06-12 00:04:25
# 2021-11-06 00:03:22
# 2018-12-05 00:02:57
# 2019-05-25 00:04:25
# 2019-01-01 00:02:49
# 2021-02-01 00:00:24
# 2021-07-14 00:00:17
# 2021-05-23 00:01:16
# 2021-12-09 06:22:05
# 2019-03-11 00:00:21
# 2019-08-06 00:01:42
# 2019-08-14 00:54:21
# 2019-03-11 00:04:15
# 2021-12-11 00:02:00
# 2022-02-16 00:02:15
# 2019-04-05 00:04:13
# 2022-02-25 00:02:54
# 2021-09-19 00:00:16
# 2019-08-17 00:00:56
# 2019-08-16 00:00:35
# 2019-06-27 00:00:03
# 2021-11-27 11:48:00
# 2019-06-27 00:00:53
# 2019-08-17 11:32:32
# 2019-06-27 00:02:26
# 2019-08-16 00:01:20
# 2019-06-09 00:00:34
# 2015-12-05 00:00:51.037000
# 2018-09-30 00:03:02
# 2018-06-20 00:04:30
# 2015-12-05 00:01:23.363000
# Epoch 61, train loss: 0.263988
# Epoch 62, train loss: 0.185058
# Epoch 63, train loss: 0.264535
# Epoch 64, train loss: 0.283556
# Epoch 65, train loss: 0.242264
# Epoch 66, train loss: 0.322132
# Epoch 67, train loss: 0.218568
# Epoch 68, train loss: 0.240020
# Epoch 69, train loss: 0.244132
# Epoch 70, train loss: 0.182758
# Epoch 71, train loss: 0.254973
# Epoch 72, train loss: 0.245136
# Epoch 73, train loss: 0.236336
# Epoch 74, train loss: 0.260544
# Epoch 75, train loss: 0.181030
# Epoch 76, train loss: 0.227575
# Epoch 77, train loss: 0.241992
# Epoch 78, train loss: 0.250437
# Epoch 79, train loss: 0.244598
# 2015-12-05 00:00:51.037000
# Reading 209 segments
# Building dataset, requesting data from 0 to 209
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 209 continuous time series
# Data shape: (8611, 6), Train/test: 1/8610
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold1_rmse\pretrain
# 2018-09-30 00:03:02
# Reading 10 segments
# Building dataset, requesting data from 0 to 10
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 10 continuous time series
# Data shape: (11829, 6), Train/test: 1/11828
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold1_rmse\pretrain
# 2018-06-20 00:04:30
# Reading 22 segments
# Building dataset, requesting data from 0 to 22
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 22 continuous time series
# Data shape: (11623, 6), Train/test: 1/11622
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold1_rmse\pretrain
# 2015-12-05 00:01:23.363000
# Reading 418 segments
# Building dataset, requesting data from 0 to 418
# ############################ Data structure summary ############################
# Hypo/no_hypo: 1/0
# Found 418 continuous time series
# Data shape: (7434, 6), Train/test: 1/7433
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold1_rmse\pretrain
# 2016-08-25 00:39:41.582000
# Reading 346 segments
# Building dataset, requesting data from 0 to 346
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 346 continuous time series
# Data shape: (8101, 6), Train/test: 1/8100
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold1_rmse\pretrain
# 2017-06-16 00:04:15
# Reading 20 segments
# Building dataset, requesting data from 0 to 20
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 20 continuous time series
# Data shape: (11449, 6), Train/test: 1/11448
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold1_rmse\pretrain
# 2017-03-17 00:03:34
# Reading 44 segments
# Building dataset, requesting data from 0 to 44
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 44 continuous time series
# Data shape: (10753, 6), Train/test: 1/10752
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold1_rmse\pretrain
# 2017-11-11 00:03:09
# Reading 24 segments
# Building dataset, requesting data from 0 to 24
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 24 continuous time series
# Data shape: (11541, 6), Train/test: 1/11540
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold1_rmse\pretrain
# 2017-10-04 00:02:14
# Reading 12 segments
# Building dataset, requesting data from 0 to 12
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 12 continuous time series
# Data shape: (11389, 6), Train/test: 1/11388
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold1_rmse\pretrain
# 2018-08-14 04:16:19
# Reading 21 segments
# Building dataset, requesting data from 0 to 21
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 21 continuous time series
# Data shape: (11340, 6), Train/test: 1/11339
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold1_rmse\pretrain
# 2019-04-10 01:29:52
# Reading 11 segments
# Building dataset, requesting data from 0 to 11
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 11 continuous time series
# Data shape: (11744, 6), Train/test: 1/11743
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_f
# Epoch 30, train loss: 0.275205
# Epoch 31, train loss: 0.261455
# Epoch 32, train loss: 0.290514
# Epoch 33, train loss: 0.245186
# Epoch 34, train loss: 0.211026
# Epoch 35, train loss: 0.243907
# Epoch 36, train loss: 0.277950
# Epoch 37, train loss: 0.227778
# Epoch 38, train loss: 0.226952
# Epoch 39, train loss: 0.282555
# Epoch 40, train loss: 0.227083
# Epoch 41, train loss: 0.276241
# Epoch 42, train loss: 0.240232
# Epoch 43, train loss: 0.219821
# Epoch 44, train loss: 0.297407
# Epoch 45, train loss: 0.247033
# Epoch 46, train loss: 0.201889
# Epoch 47, train loss: 0.271044
# Epoch 48, train loss: 0.238977
# Epoch 49, train loss: 0.329956
# Epoch 50, train loss: 0.254638
# Epoch 51, train loss: 0.267602
# Epoch 52, train loss: 0.209741
# Epoch 53, train loss: 0.200705
# Epoch 54, train loss: 0.259900
# Epoch 55, train loss: 0.230988
# Epoch 56, train loss: 0.261925
# Epoch 57, train loss: 0.220083
# Epoch 58, train loss: 0.250583
# Epoch 59, train loss: 0.239636
# Epoch 60, train loss: 0.277275
# Epoch 61, train loss: 0.276150
# Epoch 62, train loss: 0.230434
# Epoch 63, train loss: 0.287419
# Epoch 64, train loss: 0.265050
# Epoch 65, train loss: 0.223593
# Epoch 66, train loss: 0.182115
# Epoch 67, train loss: 0.265716
# Epoch 68, train loss: 0.290488
# Epoch 69, train loss: 0.217567
# Epoch 70, train loss: 0.255415
# Epoch 71, train loss: 0.250446
# Epoch 72, train loss: 0.226436
# Epoch 73, train loss: 0.197989
# Epoch 74, train loss: 0.276480
# Epoch 75, train loss: 0.284120
# Epoch 76, train loss: 0.247582
# Epoch 77, train loss: 0.231081
# Epoch 78, train loss: 0.236693
# Epoch 79, train loss: 0.228495
# 2019-06-09 00:04:51
# Reading 12 segments
# Building dataset, requesting data from 0 to 12
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 12 continuous time series
# Data shape: (11783, 6), Train/test: 1/11782
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold2_rmse\pretrain
# 2019-06-04 02:21:39
# Reading 48 segments
# Building dataset, requesting data from 0 to 48
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 48 continuous time series
# Data shape: (10688, 6), Train/test: 1/10687
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold2_rmse\pretrain
# 2019-09-05 00:01:34
# Reading 18 segments
# Building dataset, requesting data from 0 to 18
# ############################ Data structure summary ############################
# Hypo/no_hypo: 1/0
# Found 18 continuous time series
# Data shape: (11428, 6), Train/test: 1/11427
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold2_rmse\pretrain
# 2019-10-02 00:01:19
# Reading 8 segments
# Building dataset, requesting data from 0 to 8
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 8 continuous time series
# Data shape: (11857, 6), Train/test: 1/11856
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold2_rmse\pretrain
# 2019-12-25 00:02:52
# Reading 18 segments
# Building dataset, requesting data from 0 to 18
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 18 continuous time series
# Data shape: (11736, 6), Train/test: 1/11735
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold2_rmse\pretrain
# 2020-01-01 00:03:08
# Reading 6 segments
# Building dataset, requesting data from 0 to 6
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 6 continuous time series
# Data shape: (11929, 6), Train/test: 1/11928
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold2_rmse\pretrain
# 2019-11-24 00:04:24
# Reading 9 segments
# Building dataset, requesting data from 0 to 9
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 9 continuous time series
# Data shape: (11771, 6), Train/test: 1/11770
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold2_rmse\pretrain
# 2020-04-09 00:00:29
# Reading 11 segments
# Building dataset, requesting data from 0 to 11
# ############################ Data structure summary ############################
# Hypo/no_hypo: 1/0
# Found 11 continuous time series
# Data shape: (11771, 6), Train/test: 1/11770
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold2_rmse\pretrain
# 2020-05-14 00:00:34
# Reading 25 segments
# Building dataset, requesting data from 0 to 25
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 25 continuous time series
# Data shape: (11437, 6), Train/test: 1/11436
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold2_rmse\pretrain
# 2021-02-14 00:04:12
# Reading 27 segments
# Building dataset, requesting data from 0 to 27
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 27 continuous time series
# Data shape: (11432, 6), Train/test: 1/11431
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold2_rmse\pretrain
# 2020-09-16 00:03:53
# Reading 10 segments
# Building dataset, requesting data from 0 to 10
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 10 continuous time series
# Data shape: (11868, 6), Train/test: 1/11867
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold2_rmse\pretrain
# 2015-12-05 00:00:51.037000
# 2018-09-30 00:03:02
# 2018-06-20 00:04:30
# 2019-06-09 00:04:51
# 2019-06-04 02:21:39
# 2019-09-05 00:01:34
# 2019-10-02 00:01:19
# 2019-12-25 00:02:52
# 2020-01-01 00:03:08
# 2019-11-24 00:04:24
# 2020-04-09 00:00:29
# 2015-12-05 00:01:23.363000
# 2020-05-14 00:00:34
# 2021-02-14 00:04:12
# 2020-09-16 00:03:53
# 2016-08-25 00:39:41.582000
# 2021-05-23 00:01:16
# 2021-12-09 06:22:05
# 2019-03-11 00:00:21
# 2019-08-06 00:01:42
# 2019-08-14 00:54:21
# 2019-03-11 00:04:15
# 2017-06-16 00:04:15
# 2021-12-11 00:02:00
# 2022-02-16 00:02:15
# 2019-04-05 00:04:13
# 2022-02-25 00:02:54
# 2021-09-19 00:00:16
# 2019-08-17 00:00:56
# 2019-08-16 00:00:35
# 2019-06-27 00:00:03
# 2021-11-27 11:48:00
# 2019-06-27 00:00:53
# 2017-03-17 00:03:34
# 2019-08-17 11:32:32
# 2019-06-27 00:02:26
# 2019-08-16 00:01:20
# 2019-06-09 00:00:34
# 2017-11-11 00:03:09
# 2017-10-04 00:02:14
# 2018-08-14 04:16:19
# 2019-04-10 01:29:52
# 2020-06-26 00:03:03
# 2021-03-14 00:02:30
# 2021-06-30 00:00:12
# 2021-02-26 00:03:54
# 2021-06-12 00:04:25
# 2021-11-06 00:03:22
# 2018-12-05 00:02:57
# 2019-05-25 00:04:25
# 2019-01-01 00:02:49
# 2021-02-01 00:00:24
# 2021-07-14 00:00:17
# 2019-06-09 00:04:51
# Reading 12 segments
# Building dataset, requesting data from 0 to 2149
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 17613/440743
# Found 2149 continuous time series
# Data shape: (458358, 6), Train/test: 458356/2
# Train test ratio: 229178.00
# ################################################################################
# Feature size is:
# 0
# In regressor, x =
# Tensor("x:0", shape=(None, 6), dtype=float32)
# In regressor, y =
# Tensor("add:0", shape=(None, 6), dtype=float32)
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 21 continuous time series
# Data shape: (11617, 6), Train/test: 1/11616
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold3_rmse\pretrain
# 2021-03-14 00:02:30
# Reading 59 segments
# Building dataset, requesting data from 0 to 59
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 59 continuous time series
# Data shape: (9961, 6), Train/test: 1/9960
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold3_rmse\pretrain
# 2021-06-30 00:00:12
# Reading 9 segments
# Building dataset, requesting data from 0 to 9
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 9 continuous time series
# Data shape: (11796, 6), Train/test: 1/11795
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold3_rmse\pretrain
# 2021-02-26 00:03:54
# Reading 14 segments
# Building dataset, requesting data from 0 to 14
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 14 continuous time series
# Data shape: (11691, 6), Train/test: 1/11690
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold3_rmse\pretrain
# 2021-06-12 00:04:25
# Reading 8 segments
# Building dataset, requesting data from 0 to 8
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 8 continuous time series
# Data shape: (11879, 6), Train/test: 1/11878
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold3_rmse\pretrain
# 2021-11-06 00:03:22
# Reading 8 segments
# Building dataset, requesting data from 0 to 8
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 8 continuous time series
# Data shape: (11810, 6), Train/test: 1/11809
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold3_rmse\pretrain
# 2018-12-05 00:02:57
# Reading 548 segments
# Building dataset, requesting data from 0 to 548
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 548 continuous time series
# Data shape: (6578, 6), Train/test: 1/6577
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold3_rmse\pretrain
# 2019-05-25 00:04:25
# Reading 13 segments
# Building dataset, requesting data from 0 to 13
# ############################ Data structure summary ############################
# Hypo/no_hypo: 1/0
# Found 13 continuous time series
# Data shape: (11790, 6), Train/test: 1/11789
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold3_rmse\pretrain
# 2019-01-01 00:02:49
# Reading 5 segments
# Building dataset, requesting data from 0 to 5
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 5 continuous time series
# Data shape: (11941, 6), Train/test: 1/11940
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold3_rmse\pretrain
# 2021-02-01 00:00:24
# Reading 19 segments
# Building dataset, requesting data from 0 to 19
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 19 continuous time series
# Data shape: (11706, 6), Train/test: 1/11705
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold3_rmse\pretrain
# 2021-07-14 00:00:17
# Reading 12 segments
# Building dataset, requesting data from 0 to 12
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 12 continuous time series
# Data shape: (11705, 6), Train/test: 1/11704
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold3_rmse\pretrain
# 2015-12-05 00:00:51.037000
# 2018-09-30 00:03:02
# 2018-06-20 00:04:30
# 2019-06-09 00:04:51
# 2019-06-04 02:21:39
# 2019-09-05 00:01:34
# 2019-10-02 00:01:19
# 2019-12-25 00:02:52
# 2020-01-01 00:03:08
# 2019-11-24 00:04:24
# 2020-04-09 00:00:29
# 2015-12-05 00:01:23.363000
# 2020-05-14 00:00:34
# 2021-02-14 00:04:12
# 2020-09-16 00:03:53
# 2020-06-26 00:03:03
# 2021-03-14 00:02:30
# 2021-06-30 00:00:12
# 2021-02-26 00:03:54
# 2021-06-12 00:04:25
# 2021-11-06 00:03:22
# 2018-12-05 00:02:57
# 2016-08-25 00:39:41.582000
# 2019-05-25 00:04:25
# 2019-01-01 00:02:49
# 2021-02-01 00:00:24
# 2021-07-14 00:00:17
# 2017-06-16 00:04:15
# 2019-08-17 00:00:56
# 2019-08-16 00:00:35
# 2019-06-27 00:00:03
# 2021-11-27 11:48:00
# Epoch 50, train loss: 0.247062
# Epoch 51, train loss: 0.247831
# Epoch 52, train loss: 0.254116
# Epoch 53, train loss: 0.242557
# Epoch 54, train loss: 0.232331
# Epoch 55, train loss: 0.205603
# Epoch 56, train loss: 0.214637
# Epoch 57, train loss: 0.219071
# Epoch 58, train loss: 0.235012
# Epoch 59, train loss: 0.216921
# Epoch 60, train loss: 0.241398
# Epoch 61, train loss: 0.258453
# Epoch 62, train loss: 0.280801
# Epoch 63, train loss: 0.238250
# Epoch 64, train loss: 0.239257
# Epoch 65, train loss: 0.203658
# Epoch 66, train loss: 0.235907
# Epoch 67, train loss: 0.269770
# Epoch 68, train loss: 0.222060
# Epoch 69, train loss: 0.236211
# Epoch 70, train loss: 0.255940
# Epoch 71, train loss: 0.246337
# Epoch 72, train loss: 0.276987
# Epoch 73, train loss: 0.223448
# Epoch 74, train loss: 0.203530
# Epoch 75, train loss: 0.231137
# Epoch 76, train loss: 0.208883
# Epoch 77, train loss: 0.217365
# Epoch 78, train loss: 0.229191
# Epoch 79, train loss: 0.212886
# 2021-05-23 00:01:16
# Reading 10 segments
# Building dataset, requesting data from 0 to 10
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 10 continuous time series
# Data shape: (11523, 6), Train/test: 1/11522
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold4_rmse\pretrain
# 2021-12-09 06:22:05
# Reading 9 segments
# Building dataset, requesting data from 0 to 9
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 9 continuous time series
# Data shape: (11733, 6), Train/test: 1/11732
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold4_rmse\pretrain
# 2019-03-11 00:00:21
# Reading 28 segments
# Building dataset, requesting data from 0 to 28
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 28 continuous time series
# Data shape: (11313, 6), Train/test: 1/11312
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold4_rmse\pretrain
# 2019-08-06 00:01:42
# Reading 22 segments
# Building dataset, requesting data from 0 to 22
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 22 continuous time series
# Data shape: (11596, 6), Train/test: 1/11595
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold4_rmse\pretrain
# 2019-08-14 00:54:21
# Reading 15 segments
# Building dataset, requesting data from 0 to 15
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 15 continuous time series
# Data shape: (11621, 6), Train/test: 1/11620
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold4_rmse\pretrain
# 2019-03-11 00:04:15
# Reading 38 segments
# Building dataset, requesting data from 0 to 38
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 38 continuous time series
# Data shape: (11293, 6), Train/test: 1/11292
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold4_rmse\pretrain
# 2021-12-11 00:02:00
# Reading 31 segments
# Building dataset, requesting data from 0 to 31
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 31 continuous time series
# Data shape: (11563, 6), Train/test: 1/11562
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold4_rmse\pretrain
# 2022-02-16 00:02:15
# Reading 29 segments
# Building dataset, requesting data from 0 to 29
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 29 continuous time series
# Data shape: (11671, 6), Train/test: 1/11670
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold4_rmse\pretrain
# 2019-04-05 00:04:13
# Reading 28 segments
# Building dataset, requesting data from 0 to 28
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 28 continuous time series
# Data shape: (11591, 6), Train/test: 1/11590
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold4_rmse\pretrain
# 2022-02-25 00:02:54
# Reading 39 segments
# Building dataset, requesting data from 0 to 39
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 39 continuous time series
# Data shape: (11514, 6), Train/test: 1/11513
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold4_rmse\pretrain
# 2021-09-19 00:00:16
# Reading 34 segments
# Building dataset, requesting data from 0 to 34
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold5_rmse\pretrain
# 2019-08-17 11:32:32
# Reading 395 segments
# Building dataset, requesting data from 0 to 395
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 395 continuous time series
# Data shape: (6287, 6), Train/test: 1/6286
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold5_rmse\pretrain
# 2019-06-27 00:02:26
# Reading 22 segments
# Building dataset, requesting data from 0 to 22
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 22 continuous time series
# Data shape: (8945, 6), Train/test: 1/8944
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold5_rmse\pretrain
# 2019-08-16 00:01:20
# Reading 8 segments
# Building dataset, requesting data from 0 to 8
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 8 continuous time series
# Data shape: (8889, 6), Train/test: 1/8888
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold5_rmse\pretrain
# 2019-06-09 00:00:34
# Reading 30 segments
# Building dataset, requesting data from 0 to 30
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 30 continuous time series
# Data shape: (8093, 6), Train/test: 1/8092
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_fold5_rmse\pretrain
# 2019-06-09 00:04:51
# 2019-06-04 02:21:39
# 2019-09-05 00:01:34
# 2019-10-02 00:01:19
# 2019-12-25 00:02:52
# 2020-01-01 00:03:08
# 2019-11-24 00:04:24
# 2020-04-09 00:00:29
# 2020-05-14 00:00:34
# 2021-02-14 00:04:12
# 2020-09-16 00:03:53
# 2020-06-26 00:03:03
# 2021-03-14 00:02:30
# 2021-06-30 00:00:12
# 2021-02-26 00:03:54
# 2021-06-12 00:04:25
# 2021-11-06 00:03:22
# 2018-12-05 00:02:57
# 2019-05-25 00:04:25
# 2019-01-01 00:02:49
# 2021-02-01 00:00:24
# 2021-07-14 00:00:17
# 2021-05-23 00:01:16
# 2021-12-09 06:22:05
# 2019-03-11 00:00:21
# 2019-08-06 00:01:42
# 2019-08-14 00:54:21
# 2019-03-11 00:04:15
# 2021-12-11 00:02:00
# 2022-02-16 00:02:15
# 2019-04-05 00:04:13
# 2022-02-25 00:02:54
# 2021-09-19 00:00:16
# 2019-08-17 00:00:56
# 2019-08-16 00:00:35
# 2019-06-27 00:00:03
# 2021-11-27 11:48:00
# 2019-06-27 00:00:53
# 2019-08-17 11:32:32
# 2019-06-27 00:02:26
# 2019-08-16 00:01:20
# 2019-06-09 00:00:34
# 2015-12-05 00:00:51.037000
# 2018-09-30 00:03:02
# 2018-06-20 00:04:30
# 2015-12-05 00:01:23.363000
# 2016-08-25 00:39:41.582000
# 2017-06-16 00:04:15
# 2017-03-17 00:03:34
# 2017-11-11 00:03:09
# 2017-10-04 00:02:14
# 2018-08-14 04:16:19
# 2019-04-10 01:29:52
# 2019-06-09 00:04:51
# Reading 12 segments
# Building dataset, requesting data from 0 to 1728
# Train data requested beyond limit, using all but last one
# ############################ Data structure summary ############################
# Hypo/no_hypo: 13785/444922
# Found 1728 continuous time series
# Data shape: (458709, 12), Train/test: 458707/2
# Train test ratio: 229353.50
# ################################################################################
# Feature size is:
# 0
# In regressor, x =
# Tensor("x:0", shape=(None, 12), dtype=float32)
# In regressor, y =
# Tensor("add:0", shape=(None, 12), dtype=float32)
# line73: Shape of y: (None, 12)
# Before L2 regularization
# Before training for loop
# int(low_fid_data.train_n / batch_size) =  7167
# Epoch 0, train loss: 0.273899
# Epoch 63, train loss: 0.237067
# Epoch 64, train loss: 0.198495
# Epoch 65, train loss: 0.272647
# Epoch 66, train loss: 0.217972
# Epoch 67, train loss: 0.215673
# Epoch 68, train loss: 0.323635
# Epoch 69, train loss: 0.237844
# Epoch 70, train loss: 0.236115
# Epoch 71, train loss: 0.224719
# Epoch 72, train loss: 0.222389
# Epoch 73, train loss: 0.231753
# Epoch 74, train loss: 0.255726
# Epoch 75, train loss: 0.204936
# Epoch 76, train loss: 0.229519
# Epoch 77, train loss: 0.289914
# Epoch 78, train loss: 0.259055
# Epoch 79, train loss: 0.251940
# 2021-05-23 00:01:16
# Reading 10 segments
# Building dataset, requesting data from 0 to 10
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 10 continuous time series
# Data shape: (11361, 24), Train/test: 1/11360
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh24_fold4_rmse\pretrain
# 2021-12-09 06:22:05
# Reading 9 segments
# Building dataset, requesting data from 0 to 9
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 9 continuous time series
# Data shape: (11607, 24), Train/test: 1/11606
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh24_fold4_rmse\pretrain
# 2019-03-11 00:00:21
# Reading 28 segments
# Building dataset, requesting data from 0 to 28
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 28 continuous time series
# Data shape: (10847, 24), Train/test: 1/10846
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh24_fold4_rmse\pretrain
# 2019-08-06 00:01:42
# Reading 22 segments
# Building dataset, requesting data from 0 to 22
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 22 continuous time series
# Data shape: (11329, 24), Train/test: 1/11328
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh24_fold4_rmse\pretrain
# 2019-08-14 00:54:21
# Reading 15 segments
# Building dataset, requesting data from 0 to 15
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 15 continuous time series
# Data shape: (11351, 24), Train/test: 1/11350
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh24_fold4_rmse\pretrain
# 2019-03-11 00:04:15
# Reading 38 segments
# Building dataset, requesting data from 0 to 38
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 38 continuous time series
# Data shape: (10627, 24), Train/test: 1/10626
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh24_fold4_rmse\pretrain
# 2021-12-11 00:02:00
# Reading 31 segments
# Building dataset, requesting data from 0 to 31
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 31 continuous time series
# Data shape: (11169, 24), Train/test: 1/11168
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh24_fold4_rmse\pretrain
# 2022-02-16 00:02:15
# Reading 29 segments
# Building dataset, requesting data from 0 to 29
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 29 continuous time series
# Data shape: (11214, 24), Train/test: 1/11213
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh24_fold4_rmse\pretrain
# 2019-04-05 00:04:13
# Reading 28 segments
# Building dataset, requesting data from 0 to 28
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 28 continuous time series
# Data shape: (11123, 24), Train/test: 1/11122
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh24_fold4_rmse\pretrain
# 2022-02-25 00:02:54
# Reading 39 segments
# Building dataset, requesting data from 0 to 39
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 39 continuous time series
# Data shape: (11189, 24), Train/test: 1/11188
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh24_fold4_rmse\pretrain
# 2021-09-19 00:00:16
# Reading 34 segments
# Building dataset, requesting data from 0 to 34
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 34 continuous time series
# Data shape: (9869, 24), Train/test: 1/9868
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh24_fold4_rmse\pretrain
# 2015-12-05 00:00:51.037000
# 2018-09-30 00:03:02
# 2018-06-20 00:04:30
# 2019-06-09 00:04:51
# 2019-06-04 02:21:39
# 2019-09-05 00:01:34
# 2019-10-02 00:01:19
# 2019-12-25 00:02:52
# 2020-01-01 00:03:08
# 2019-11-24 00:04:24
# 2020-04-09 00:00:29
# 2015-12-05 00:01:23.363000
# 2020-05-14 00:00:34
# Epoch 34, train loss: 0.182163
# Epoch 35, train loss: 0.225113
# Epoch 36, train loss: 0.231002
# Epoch 37, train loss: 0.266316
# Epoch 38, train loss: 0.214832
# Epoch 39, train loss: 0.276499
# Epoch 40, train loss: 0.218643
# Epoch 41, train loss: 0.237370
# Epoch 42, train loss: 0.288119
# Epoch 43, train loss: 0.203499
# Epoch 44, train loss: 0.223939
# Epoch 45, train loss: 0.248530
# Epoch 46, train loss: 0.196171
# Epoch 47, train loss: 0.260120
# Epoch 48, train loss: 0.294033
# Epoch 49, train loss: 0.202980
# Epoch 50, train loss: 0.196541
# Epoch 51, train loss: 0.237354
# Epoch 52, train loss: 0.300965
# Epoch 53, train loss: 0.223515
# Epoch 54, train loss: 0.277998
# Epoch 55, train loss: 0.286462
# Epoch 56, train loss: 0.271126
# Epoch 57, train loss: 0.293062
# Epoch 58, train loss: 0.279214
# Epoch 59, train loss: 0.236072
# Epoch 60, train loss: 0.250245
# Epoch 61, train loss: 0.243463
# Epoch 62, train loss: 0.294089
# Epoch 63, train loss: 0.203063
# Epoch 64, train loss: 0.222691
# Epoch 65, train loss: 0.186646
# Epoch 66, train loss: 0.216982
# Epoch 67, train loss: 0.286154
# Epoch 68, train loss: 0.248282
# Epoch 69, train loss: 0.173107
# Epoch 70, train loss: 0.254927
# Epoch 71, train loss: 0.234253
# Epoch 72, train loss: 0.255935
# Epoch 73, train loss: 0.232482
# Epoch 74, train loss: 0.257714
# Epoch 75, train loss: 0.276445
# Epoch 76, train loss: 0.209720
# Epoch 77, train loss: 0.204344
# Epoch 78, train loss: 0.289832
# Epoch 79, train loss: 0.231966
# 2019-08-17 00:00:56
# Reading 35 segments
# Building dataset, requesting data from 0 to 35
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 35 continuous time series
# Data shape: (10685, 24), Train/test: 1/10684
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh24_fold5_rmse\pretrain
# 2019-08-16 00:00:35
# Reading 24 segments
# Building dataset, requesting data from 0 to 24
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 24 continuous time series
# Data shape: (11191, 24), Train/test: 1/11190
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh24_fold5_rmse\pretrain
# 2019-06-27 00:00:03
# Reading 10 segments
# Building dataset, requesting data from 0 to 10
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 10 continuous time series
# Data shape: (11535, 24), Train/test: 1/11534
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh24_fold5_rmse\pretrain
# 2021-11-27 11:48:00
# Reading 5 segments
# Building dataset, requesting data from 0 to 5
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 5 continuous time series
# Data shape: (11666, 24), Train/test: 1/11665
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh24_fold5_rmse\pretrain
# 2019-06-27 00:00:53
# Reading 8 segments
# Building dataset, requesting data from 0 to 8
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 8 continuous time series
# Data shape: (10635, 24), Train/test: 1/10634
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh24_fold5_rmse\pretrain
# 2019-08-17 11:32:32
# Reading 395 segments
# Building dataset, requesting data from 0 to 395
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 395 continuous time series
# Data shape: (4413, 24), Train/test: 1/4412
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh24_fold5_rmse\pretrain
# 2019-06-27 00:02:26
# Reading 22 segments
# Building dataset, requesting data from 0 to 22
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 22 continuous time series
# Data shape: (8549, 24), Train/test: 1/8548
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh24_fold5_rmse\pretrain
# 2019-08-16 00:01:20
# Reading 8 segments
# Building dataset, requesting data from 0 to 8
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 8 continuous time series
# Data shape: (8763, 24), Train/test: 1/8762
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh24_fold5_rmse\pretrain
# 2019-06-09 00:00:34
# Reading 30 segments
# Building dataset, requesting data from 0 to 30
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 30 continuous time series
# Data shape: (7553, 24), Train/test: 1/7552
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh24_fold5_rmse\pretrain

# %%
for subj in file_names:
    subject = pd.read_excel(f"C:/Users/username/OneDrive/Desktop/BGprediction/DiaTrend/dataset/{subj}.xlsx","CGM")
    split_index = int(len(subject) * 0.8)
    # Split the DataFrame
    train_df = subject[:split_index]
    test_df = subject[split_index:]

    # Save the DataFrames to CSV files
    train_df.to_csv(f'C:/Users/username/OneDrive/Desktop/BGprediction/DiaTrend/train/{subj}_training_data.csv', index=False)
    test_df.to_csv(f'C:/Users/username/OneDrive/Desktop/BGprediction/DiaTrend/test/{subj}_testing_data.csv', index=False)

    # Optionally, confirm the operation
    print(f"Training data saved with {len(train_df)} records.")
    print(f"Testing data saved with {len(test_df)} records.")

# %%
# Need to do the train_test split
# First 80% in training
# Last 20% in test
# split_index = int(len(subject) * 0.8)
# # Split the DataFrame
# train_df = subject[:split_index]
# test_df = subject[split_index:]

# # Save the DataFrames to CSV files
# train_df.to_csv(f'C:/Users/username/OneDrive/Desktop/BGprediction/DiaTrend/train/{subj}_training_data.csv', index=False)
# test_df.to_csv(f'C:/Users/username/OneDrive/Desktop/BGprediction/DiaTrend/test/{subj}_testing_data.csv', index=False)

# # Optionally, confirm the operation
# print(f"Training data saved with {len(train_df)} records.")
# print(f"Testing data saved with {len(test_df)} records.")

# %%
# Assuming your DataFrame is named df
subject['date'] = pd.to_datetime(subject['date'])  # Convert 'date' column to datetime if not already
subject.sort_values('date', inplace=True)  # Sort the DataFrame by the 'date' column

# %%
# Assuming self.interval_timedelta is set, for example:
interval_timedelta = datetime.timedelta(minutes=6)  # Example timedelta of 6 minutes, providing a range for latency

# Create a list to store the results
res = []

# Initialize the first group
if not subject.empty:
    current_group = [subject.iloc[0]['mg/dl']]
    last_time = subject.iloc[0]['date']

# Iterate over rows in DataFrame starting from the second row
for index, row in subject.iloc[1:].iterrows():
    current_time = row['date']
    if (current_time - last_time) <= interval_timedelta:
        # If the time difference is within the limit, add to the current group
        current_group.append(row['mg/dl'])
    else:
        # Otherwise, start a new group
        res.append(current_group)
        current_group = [row['mg/dl']]
    last_time = current_time

# Add the last group if it's not empty
if current_group:
    res.append(current_group)

# %% [markdown]
# # Functions

# %%
def preprocess_DiaTrend(path):

    subject = pd.read_csv(path)
    subject['date'] = pd.to_datetime(subject['date'], errors='coerce')  # Convert 'date' column to datetime if not already
    print(subject['date'][0])
    subject.sort_values('date', inplace=True)  # Sort the DataFrame by the 'date' column

    # Assuming self.interval_timedelta is set, for example:
    interval_timedelta = datetime.timedelta(minutes=6)  # Example timedelta of 6 minutes, providing a range for latency

    # Create a list to store the results
    res = []

    # Initialize the first group
    if not subject.empty:
        current_group = [subject.iloc[0]['mg/dl']]
        last_time = subject.iloc[0]['date']

    # Iterate over rows in DataFrame starting from the second row
    for index, row in subject.iloc[1:].iterrows():
        current_time = row['date']
        if (current_time - last_time) <= interval_timedelta:
            # If the time difference is within the limit, add to the current group
            current_group.append(row['mg/dl'])
        else:
            # Otherwise, start a new group
            res.append(current_group)
            current_group = [row['mg/dl']]
        last_time = current_time

    # Add the last group if it's not empty
    if current_group:
        res.append(current_group)
    
    # Filter out groups with fewer than 10 glucose readings
    # res = [group for group in res if len(group) >= 10]

    return res

# %% [markdown]
# # For loop to generate res for train and test

# %%
# Fomulate a loop to create a list to include all the files in train and test datset and generate the res for each of them seperately
# C:/Users/username/OneDrive/Desktop/Modify_GenBG/modified_diatrend_subset/fold1_training/processed_cgm_data_Subject12.csv
fold_num = 2

# Correct path with raw string
train_directory_path = f'C:/Users/baiyi/OneDrive/Desktop/Modify_GenBG/modified_diatrend_subset/fold{fold_num}_training'

# List files without their extensions
train_file_names = [os.path.splitext(file)[0] for file in os.listdir(train_directory_path)
                    if os.path.isfile(os.path.join(train_directory_path, file))]

# Print the list of file names
print(train_file_names)
# Out:
# ['processed_cgm_data_Subject1', 'processed_cgm_data_Subject10', 'processed_cgm_data_Subject11', 'processed_cgm_data_Subject2', 'processed_cgm_data_Subject23', 'processed_cgm_data_Subject24', 'processed_cgm_data_Subject25', 'processed_cgm_data_Subject26', 'processed_cgm_data_Subject27', 'processed_cgm_data_Subject28', 'processed_cgm_data_Subject29', 'processed_cgm_data_Subject3', 'processed_cgm_data_Subject30', 'processed_cgm_data_Subject31', 'processed_cgm_data_Subject32', 'processed_cgm_data_Subject33', 'processed_cgm_data_Subject34', 'processed_cgm_data_Subject35', 'processed_cgm_data_Subject36', 'processed_cgm_data_Subject37', 'processed_cgm_data_Subject38', 'processed_cgm_data_Subject39', 'processed_cgm_data_Subject4', 'processed_cgm_data_Subject40', 'processed_cgm_data_Subject41', 'processed_cgm_data_Subject42', 'processed_cgm_data_Subject43', 'processed_cgm_data_Subject44', 'processed_cgm_data_Subject45', 'processed_cgm_data_Subject46', 'processed_cgm_data_Subject47', 'processed_cgm_data_Subject48', 'processed_cgm_data_Subject49', 'processed_cgm_data_Subject5', 'processed_cgm_data_Subject50', 'processed_cgm_data_Subject51', 'processed_cgm_data_Subject53', 'processed_cgm_data_Subject54', 'processed_cgm_data_Subject6', 'processed_cgm_data_Subject7', 'processed_cgm_data_Subject8', 'processed_cgm_data_Subject9']

# %%
cleaned_subjects = [s.replace("processed_cgm_data_", "") for s in train_file_names]

print(cleaned_subjects)
# Out:
# ['Subject12', 'Subject13', 'Subject14', 'Subject15', 'Subject16', 'Subject17', 'Subject18', 'Subject19', 'Subject20', 'Subject21', 'Subject22', 'Subject23', 'Subject24', 'Subject25', 'Subject26', 'Subject27', 'Subject28', 'Subject29', 'Subject30', 'Subject31', 'Subject32', 'Subject33', 'Subject34', 'Subject35', 'Subject36', 'Subject37', 'Subject38', 'Subject39', 'Subject40', 'Subject41', 'Subject42', 'Subject43', 'Subject44', 'Subject45', 'Subject46', 'Subject47', 'Subject48', 'Subject49', 'Subject50', 'Subject51', 'Subject53', 'Subject54']

# %%
# Define the directory path
test_directory_path = r'C:\Users\baiyi\OneDrive\Desktop\Modify_GenBG\modified_diatrend_subset\fold1_test'  # Use a raw string for paths on Windows

# List files without their extensions
test_file_names = [os.path.splitext(file)[0] for file in os.listdir(test_directory_path)
              if os.path.isfile(os.path.join(test_directory_path, file))]

# Print the list of file names
print(test_file_names)
# Out:
# ['processed_cgm_data_Subject1', 'processed_cgm_data_Subject10', 'processed_cgm_data_Subject11', 'processed_cgm_data_Subject2', 'processed_cgm_data_Subject3', 'processed_cgm_data_Subject4', 'processed_cgm_data_Subject5', 'processed_cgm_data_Subject6', 'processed_cgm_data_Subject7', 'processed_cgm_data_Subject8', 'processed_cgm_data_Subject9']

# %%
cleaned_test_subjects = [s.replace("processed_cgm_data_", "") for s in test_file_names]

print(cleaned_test_subjects)
# Out:
# ['Subject1', 'Subject10', 'Subject11', 'Subject2', 'Subject3', 'Subject4', 'Subject5', 'Subject6', 'Subject7', 'Subject8', 'Subject9']

# %%
train_data = dict()
for subj in train_file_names:
    print(subj)
    subj_path = f'C:/Users/baiyi/OneDrive/Desktop/Modify_GenBG/modified_diatrend_subset/fold1_training/{subj}.csv'
    reader = preprocess_DiaTrend(subj_path)
    train_data[subj] = reader
# Out:
# processed_cgm_data_Subject12
# 2019-06-09 00:04:51
# processed_cgm_data_Subject13
# 2019-06-04 02:21:39
# processed_cgm_data_Subject14
# 2019-09-05 00:01:34
# processed_cgm_data_Subject15
# 2019-10-02 00:01:19
# processed_cgm_data_Subject16
# 2019-12-25 00:02:52
# processed_cgm_data_Subject17
# 2020-01-01 00:03:08
# processed_cgm_data_Subject18
# 2019-11-24 00:04:24
# processed_cgm_data_Subject19
# 2020-04-09 00:00:29
# processed_cgm_data_Subject20
# 2020-05-14 00:00:34
# processed_cgm_data_Subject21
# 2021-02-14 00:04:12
# processed_cgm_data_Subject22
# 2020-09-16 00:03:53
# processed_cgm_data_Subject23
# 2020-06-26 00:03:03
# processed_cgm_data_Subject24
# 2021-03-14 00:02:30
# processed_cgm_data_Subject25
# 2021-06-30 00:00:12
# processed_cgm_data_Subject26
# 2021-02-26 00:03:54
# processed_cgm_data_Subject27
# 2021-06-12 00:04:25
# processed_cgm_data_Subject28
# 2021-11-06 00:03:22
# processed_cgm_data_Subject29
# 2018-12-05 00:02:57
# processed_cgm_data_Subject30
# 2019-05-25 00:04:25
# processed_cgm_data_Subject31
# 2019-01-01 00:02:49
# processed_cgm_data_Subject32
# 2021-02-01 00:00:24
# processed_cgm_data_Subject33
# 2021-07-14 00:00:17
# processed_cgm_data_Subject34
# 2021-05-23 00:01:16
# processed_cgm_data_Subject35
# 2021-12-09 06:22:05
# processed_cgm_data_Subject36
# 2019-03-11 00:00:21
# processed_cgm_data_Subject37
# 2019-08-06 00:01:42
# processed_cgm_data_Subject38
# 2019-08-14 00:54:21
# processed_cgm_data_Subject39
# 2019-03-11 00:04:15
# processed_cgm_data_Subject40
# 2021-12-11 00:02:00
# processed_cgm_data_Subject41
# 2022-02-16 00:02:15
# processed_cgm_data_Subject42
# 2019-04-05 00:04:13
# processed_cgm_data_Subject43
# 2022-02-25 00:02:54
# processed_cgm_data_Subject44
# 2021-09-19 00:00:16
# processed_cgm_data_Subject45
# 2019-08-17 00:00:56
# processed_cgm_data_Subject46
# 2019-08-16 00:00:35
# processed_cgm_data_Subject47
# 2019-06-27 00:00:03
# processed_cgm_data_Subject48
# 2021-11-27 11:48:00
# processed_cgm_data_Subject49
# 2019-06-27 00:00:53
# processed_cgm_data_Subject50
# 2019-08-17 11:32:32
# processed_cgm_data_Subject51
# 2019-06-27 00:02:26
# processed_cgm_data_Subject53
# 2019-08-16 00:01:20
# processed_cgm_data_Subject54
# 2019-06-09 00:00:34

# %%
# Have not been run
test_data = dict()
for subj in test_file_names:
    print(subj)
    subj_path = f'C:/Users/baiyi/OneDrive/Desktop/Modify_GenBG/modified_diatrend_subset/fold1_test/{subj}.csv'
    reader = preprocess_DiaTrend(subj_path)
    test_data[subj] = reader
# Out:
# processed_cgm_data_Subject1
# 2015-12-05 00:00:51.037000
# processed_cgm_data_Subject10
# 2018-09-30 00:03:02
# processed_cgm_data_Subject11
# 2018-06-20 00:04:30
# processed_cgm_data_Subject2
# 2015-12-05 00:01:23.363000
# processed_cgm_data_Subject3
# 2016-08-25 00:39:41.582000
# processed_cgm_data_Subject4
# 2017-06-16 00:04:15
# processed_cgm_data_Subject5
# 2017-03-17 00:03:34
# processed_cgm_data_Subject6
# 2017-11-11 00:03:09
# processed_cgm_data_Subject7
# 2017-10-04 00:02:14
# processed_cgm_data_Subject8
# 2018-08-14 04:16:19
# processed_cgm_data_Subject9
# 2019-04-10 01:29:52

# %%
epoch = 80
sh = 6
ph = 6
path = "../diatrend_results"

# %%
# a dumb dataset instance "C:\Users\baiyi\OneDrive\Desktop\Modify_GenBG\modified_diatrend_subset\fold1_training\processed_cgm_data_Subject12.csv"
train_dataset = CGMSDataSeg(
    "diatrend", "C:/Users/baiyi/OneDrive/Desktop/Modify_GenBG/modified_diatrend_subset/fold1_training/processed_cgm_data_Subject12.csv", 5
)
sampling_horizon = sh
prediction_horizon = ph
scale = 0.01
outtype = "Same"
# train on training dataset
# k_size, nblock, nn_size, nn_layer, learning_rate, batch_size, epoch, beta
with open(f'../diatrend_results/config.json') as json_file:
    config = json.load(json_file)
argv = (
    config["k_size"],
    config["nblock"],
    config["nn_size"],
    config["nn_layer"],
    config["learning_rate"],
    config["batch_size"],
    epoch,
    config["beta"],
)
l_type = config["loss"]
# test on patients data
outdir = os.path.join(path, f"ph_{prediction_horizon}_sh{sampling_horizon}_{l_type}")
if not os.path.exists(outdir):
    os.makedirs(outdir)
all_errs = []
# Out:
# 2019-06-09 00:04:51
# Reading 12 segments

# %%
# Loop
cleaned_subjects.sort()
standard = False  # do not use standard

train_pids = set(cleaned_subjects)
local_train_data = []
for k in train_pids:
    local_train_data += train_data["processed_cgm_data_" + k]
print(f"Pretrain data: {sum([sum(x) for x in local_train_data])}")

train_dataset.data = local_train_data
train_dataset.set_cutpoint = -1
train_dataset.reset(
    sampling_horizon,
    prediction_horizon,
    scale,
    100,
    False,
    outtype,
    1,
    standard,
)
regressor(train_dataset, *argv, l_type, outdir)

# %%
all_errs = []
for pid in cleaned_test_subjects: # First 9 as subset, can be an example
    # train_pids = set(cleaned_subjects)
    # local_train_data = []
    # for k in train_pids:
    #     local_train_data += train_data[k + "_training_data"]
    # print(f"Pretrain data: {sum([sum(x) for x in local_train_data])}")
    
    # train_dataset.data = local_train_data
    # train_dataset.set_cutpoint = -1
    # train_dataset.reset(
    #     sampling_horizon,
    #     prediction_horizon,
    #     scale,
    #     100,
    #     False,
    #     outtype,
    #     1,
    #     standard,
    # )
    # regressor(train_dataset, *argv, l_type, outdir)
    # Fine-tune and test
    target_test_dataset = CGMSDataSeg(
    "diatrend", f"C:/Users/baiyi/OneDrive/Desktop/Modify_GenBG/modified_diatrend_subset/fold1_test/processed_cgm_data_{pid}.csv", 5
    )
    target_test_dataset.set_cutpoint = 1
    target_test_dataset.reset(
        sampling_horizon,
        prediction_horizon,
        scale,
        0.01,
        False,
        outtype,
        1,
        standard,
    )

    # target_train_dataset = CGMSDataSeg(
    # "ohio", f"C:/Users/baiyi/OneDrive/Desktop/Modify_GenBG/modified_diatrend_subset/fold1_training/{pid}.csv", 5
    # )
    # target_train_dataset.set_cutpoint = -1
    # target_train_dataset.reset(
    #     sampling_horizon,
    #     prediction_horizon,
    #     scale,
    #     100,
    #     False,
    #     outtype,
    #     1,
    #     standard,
    # )
    err, labels = test_ckpt(target_test_dataset, outdir)
    # errs = [err]
    # transfer_res = [labels]
    # for i in range(1, 2):
    #     err, labels = regressor_transfer(
    #         target_train_dataset,
    #         target_test_dataset,
    #         config["batch_size"],
    #         epoch,
    #         outdir,
    #         i,
    #     )
    #     errs.append(err)
    #     transfer_res.append(labels)
    # transfer_res = np.concatenate(transfer_res, axis=1)
    np.savetxt(
        f"{outdir}/{pid}.txt",
        [err],
        fmt="%.4f",
    )
    all_errs.append([str(pid), err]) 
all_errs = np.array(all_errs, dtype=object)  # Use dtype=object to handle mixed types
np.savetxt(f"{outdir}/errors.txt", all_errs, fmt="%s %.4f")
# label pair:(groundTruth, y_pred)
# Out:
# 2015-12-05 00:00:51.037000
# Reading 209 segments
# Building dataset, requesting data from 0 to 209
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 209 continuous time series
# Data shape: (8611, 6), Train/test: 1/8610
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_rmse\pretrain
# 2018-09-30 00:03:02
# Reading 10 segments
# Building dataset, requesting data from 0 to 10
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 10 continuous time series
# Data shape: (11829, 6), Train/test: 1/11828
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_rmse\pretrain
# 2018-06-20 00:04:30
# Reading 22 segments
# Building dataset, requesting data from 0 to 22
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 22 continuous time series
# Data shape: (11623, 6), Train/test: 1/11622
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_rmse\pretrain
# 2015-12-05 00:01:23.363000
# Reading 418 segments
# Building dataset, requesting data from 0 to 418
# ############################ Data structure summary ############################
# Hypo/no_hypo: 1/0
# Found 418 continuous time series
# Data shape: (7434, 6), Train/test: 1/7433
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_rmse\pretrain
# 2016-08-25 00:39:41.582000
# Reading 346 segments
# Building dataset, requesting data from 0 to 346
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 346 continuous time series
# Data shape: (8101, 6), Train/test: 1/8100
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_rmse\pretrain
# 2017-06-16 00:04:15
# Reading 20 segments
# Building dataset, requesting data from 0 to 20
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 20 continuous time series
# Data shape: (11449, 6), Train/test: 1/11448
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_rmse\pretrain
# 2017-03-17 00:03:34
# Reading 44 segments
# Building dataset, requesting data from 0 to 44
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 44 continuous time series
# Data shape: (10753, 6), Train/test: 1/10752
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_rmse\pretrain
# 2017-11-11 00:03:09
# Reading 24 segments
# Building dataset, requesting data from 0 to 24
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 24 continuous time series
# Data shape: (11541, 6), Train/test: 1/11540
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_rmse\pretrain
# 2017-10-04 00:02:14
# Reading 12 segments
# Building dataset, requesting data from 0 to 12
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 12 continuous time series
# Data shape: (11389, 6), Train/test: 1/11388
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_rmse\pretrain
# 2018-08-14 04:16:19
# Reading 21 segments
# Building dataset, requesting data from 0 to 21
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 21 continuous time series
# Data shape: (11340, 6), Train/test: 1/11339
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_rmse\pretrain
# 2019-04-10 01:29:52
# Reading 11 segments
# Building dataset, requesting data from 0 to 11
# ############################ Data structure summary ############################
# Hypo/no_hypo: 0/1
# Found 11 continuous time series
# Data shape: (11744, 6), Train/test: 1/11743
# Train test ratio: 0.00
# ################################################################################
# INFO:tensorflow:Restoring parameters from ../diatrend_results\ph_6_sh6_rmse\pretrain

# %%
all_errs

# %%
# Convert the second and third columns to floats
second_column = all_errs[:, 1].astype(float)
third_column = all_errs[:, 2].astype(float)

# Calculate the average
average_second_column = np.mean(second_column)
average_third_column = np.mean(third_column)

print("Average of the second column:", average_second_column)
print("Average of the third column:", average_third_column)

# %%
# Convert the second and third columns to floats
second_column = all_errs[:, 1].astype(float)
third_column = all_errs[:, 2].astype(float)

# Calculate the average
average_second_column = np.mean(second_column)
average_third_column = np.mean(third_column)

print("Average of the second column:", average_second_column)
print("Average of the third column:", average_third_column)
# Out:
# Average of the second column: 0.23931833875
# Average of the third column: 0.23320475625

# %%
# Also, if the previous cell run into an issue but all result txt files are ready
# You can run this to evaluate:
import argparse
import json
import os
import pandas as pd
import os
import datetime
import numpy as np

# List all files and directories in the current directory
files_and_directories = os.listdir('.')

# Filter for files that end with .txt
txt_files = [file for file in files_and_directories if file.endswith('.txt')]


# Read the data from the text file
def calcuate_rmse(file):
    data = np.loadtxt(file)  # Make sure to replace 'data.txt' with your actual file path
    print(file)
    # Splitting the data into groundtruth and predictions
    groundtruth = data[:, 0]  # First column as ground truth (also same as third column)
    predictions_1 = data[:, 1]  # Second column as predictions from method 1
    predictions_2 = data[:, 3]  # Fourth column as predictions from method 2

    # Function to calculate RMSE
    def calculate_rmse(true_values, predictions):
        mse = np.mean((true_values - predictions) ** 2)
        rmse = np.sqrt(mse)
        return rmse

    # Calculate RMSE for each method
    rmse_method_1 = calculate_rmse(groundtruth, predictions_1)
    rmse_method_2 = calculate_rmse(groundtruth, predictions_2)

    print("RMSE for Method 1:", rmse_method_1)
    print("RMSE for Method 2:", rmse_method_2)
    return rmse_method_1


rmse_list = []
for f in txt_files[1:]:
    rmse1 = calcuate_rmse(f)
    print(rmse1)
    rmse_list.append(rmse1)

print(np.average(rmse_list))

print(rmse_list)
